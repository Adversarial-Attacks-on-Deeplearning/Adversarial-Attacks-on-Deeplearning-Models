# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from GTSRB_utils import GTSRB_CLASSES, predict_traffic_sign, create_subset_loader, load_ppm_image

# %%
from tensorflow.keras.models import load_model
model = load_model("TrafficSigns_EfficientNetB1.keras")

# %%
import matplotlib.pyplot as plt
from PIL import Image

def display_ppm_image(file_path):
    """
    Display a .ppm image using Pillow and Matplotlib.

    Parameters:
    -----------
    file_path : str
        Path to the .ppm image file.
    """
    # Open the .ppm file
    with Image.open(file_path) as img:
        # Convert to a format Matplotlib can handle (e.g., RGB)
        #img_rgb = img.convert("RGB")

        # Display using matplotlib
        plt.imshow(img)
        plt.axis('off')  # Hide axis for cleaner display
        plt.title(f"Displaying: {file_path}")
        plt.show()

# Example usage:
display_ppm_image("00000.ppm")

# %%
import tensorflow as tf
from PIL import Image
import numpy as np



image_path = "00000.ppm"
# Load and preprocess the image with the correct target size (240x240)
image = load_ppm_image(image_path, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign(image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step
# Prediction shape: (1, 43)
# Predicted class: Vehicles over 3.5 tons prohibited
# np.int64(16)

# %%
from PIL import Image

def convert_jfif_to_ppm(input_path, output_path):
    """
    Convert a .jfif (JPEG) file to a .ppm file using Pillow.

    Parameters:
    -----------
    input_path : str
        Path to the input .jfif file.
    output_path : str
        Path to the output .ppm file.
    """
    # Open the JFIF image
    with Image.open(input_path) as img:
        # Convert to RGB (PPM is typically an RGB format)
        img_rgb = img.convert("RGB")
        # Save as PPM
        img_rgb.save(output_path, format="PPM")

# Example usage:
convert_jfif_to_ppm("Limit20.jfif", "ppm_limit20.ppm")
new_photo="ppm_limit20.ppm"
display_ppm_image(new_photo)

# %%
from PIL import Image

with Image.open("00001.ppm") as img:
    print("Image size:", img.size)  # (width, height)
# Out:
# Image size: (42, 45)

# %%
# Load and preprocess the image with the correct target size (240x240)
limit20image = load_ppm_image(new_photo, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign(limit20image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Prediction shape: (1, 43)
# Predicted class: Speed limit 20
# np.int64(0)

# %%
from PIL import Image
import numpy as np
import tensorflow as tf

def ppm_to_tensor_tf(file_path):
    """
    Load a .ppm file and convert it to a TensorFlow tensor.
    Returns a 4D tensor of shape (1, height, width, 3).
    """
    with Image.open(file_path) as img:
        # Convert the image to RGB (just in case it's not already)
        img_rgb = img.convert("RGB")

        # Convert the PIL image to a NumPy array
        img_np = np.array(img_rgb)

        # Convert the NumPy array to a TF tensor
        # Shape: (height, width, channels)
        img_tensor = tf.convert_to_tensor(img_np, dtype=tf.float32)

        # Optionally, add a batch dimension at the start
        img_tensor = tf.expand_dims(img_tensor, axis=0)  # shape -> (1, H, W, 3)

    return img_tensor

# Usage:
tensored_image = ppm_to_tensor_tf("00001.ppm")
print(tensored_image.shape)  # e.g., (1, 224, 224, 3)
# Out:
# (1, 45, 42, 3)

# %%
def predict_traffic_sign_all(img_input, model, class_mapping):
    """
    Accepts a tensor (rank 3 or 4), raw image bytes, or a file path.
    Prints the probability for each class and the predicted class.
    """
    # Get predictions
    prop = model.predict(img_input)
    print("Prediction shape:", prop.shape)

    # Assuming the output is of shape (1, num_classes)
    probabilities = prop[0]

    # Print probabilities for all classes
    for i, p in enumerate(probabilities):
        print(f"Class {i} ({class_mapping[i]}): {p:.4f}")

    # Determine the predicted class
    class_id = np.argmax(probabilities)
    print("Predicted class:", class_mapping[class_id])

    return class_id

# %%
import numpy as np
import tensorflow as tf
from PIL import Image
from GTSRB_utils import GTSRB_CLASSES, load_ppm_image, predict_traffic_sign

def simba_attack(image_tensor, true_label, model, num_iters=2000, epsilon=0.2, print_every=10):
    """
    image_tensor: TensorFlow tensor of shape (1, H, W, 3) in [0, 255]
    true_label: Integer label (the true class of the image)
    model: TensorFlow/Keras model used for prediction
    num_iters: Maximum number of iterations (queries)
    epsilon: Perturbation magnitude for each pixel update
    print_every: Frequency (in iterations) at which to print detailed logs
    """
    # Adapt epsilon value for models that accept unnormalized images
    epsilon = epsilon * 255

    # Convert image tensor to numpy array for manipulation
    adv = image_tensor.numpy()  # shape: (1, H, W, 3)
    H, W, C = adv.shape[1], adv.shape[2], adv.shape[3]
    n_dims = H * W * C

    # Generate a random permutation of pixel indices
    perm = np.random.permutation(n_dims)

   # Get the initial probability for the true class
    pred = model.predict(adv)
    true_prob = pred[0][true_label]
    print("Initial true class probability for label {}: {:.4f}".format(true_label, true_prob))


    # Check initial prediction (if already flipped, no need to attack)
    current_pred = np.argmax(pred[0])
    if current_pred != true_label:
        print("Initial prediction is already different from the true label.")
        return tf.convert_to_tensor(adv, dtype=tf.float32)

    # Loop over the maximum number of iterations
    for i in range(num_iters):
        # Wrap around the permutation if i >= n_dims
        idx = perm[i % n_dims]
        # Convert flat index to (row, col, channel)
        channel = idx % C
        temp = idx // C
        col = temp % W
        row = temp // W

        # Create a perturbation only at the selected pixel and channel
        perturb = np.zeros_like(adv)
        perturb[0, row, col, channel] = epsilon

        # Try positive perturbation
        adv_pos = np.clip(adv + perturb, 0, 255)
        prob_pos = model.predict(adv_pos)
        pos_true_prob = prob_pos[0][true_label]
        diff_pos = pos_true_prob - true_prob

        # For an untargeted attack, we want to lower the confidence of the true class
        if pos_true_prob < true_prob:
            adv = adv_pos
            print(f"Iteration {i}: +epsilon -> pixel=({row},{col},{channel}), "
                  f"old_prob={true_prob:.6f}, new_prob={pos_true_prob:.6f}, diff={diff_pos:.6f}")
            true_prob = pos_true_prob
        else:
            # Try negative perturbation if positive did not help
            adv_neg = np.clip(adv - perturb, 0, 255)
            prob_neg = model.predict(adv_neg)
            neg_true_prob = prob_neg[0][true_label]
            diff_neg = neg_true_prob - true_prob

            if neg_true_prob < true_prob:
                adv = adv_neg
                print(f"Iteration {i}: -epsilon -> pixel=({row},{col},{channel}), "
                      f"old_prob={true_prob:.6f}, new_prob={neg_true_prob:.6f}, diff={diff_neg:.6f}")
                true_prob = neg_true_prob
            else:
                # Optionally print status even if no update occurred
                if (i % print_every) == 0:
                    print(f"Iteration {i}: No update at pixel=({row},{col},{channel}). "
                          f"pos_diff={diff_pos:.6f}, neg_diff={diff_neg:.6f}, current_prob={true_prob:.6f}")

        # Check if the true class is no longer the highest predicted
        current_pred = np.argmax(model.predict(adv)[0])
        if current_pred != true_label:
            print(f"Attack successful at iteration {i}: predicted class flipped to {current_pred} != true label {true_label}")
            break

    print("Attack finished after {} iterations. Final true class probability: {:.4f}".format(i+1, true_prob))
    # Return the adversarial image as a TensorFlow tensor
    adv_tensor = tf.convert_to_tensor(adv, dtype=tf.float32)
    return adv_tensor

# %% [markdown]
# **First Image testing for the Attack**

# %%
# Example usage:
convert_jfif_to_ppm("No.jfif", "Restricted.ppm")
new_photo="Restricted.ppm"
display_ppm_image(new_photo)

# %%
new_image_path = "Restricted.ppm"
# Load and preprocess the image with the correct target size (240x240)
image = load_ppm_image(new_image_path, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign_all(image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Prediction shape: (1, 43)
# Class 0 (Speed limit 20): 0.0000
# Class 1 (Speed limit 30): 0.0000
# Class 2 (Speed limit 50): 0.0000
# Class 3 (Speed limit 60): 0.0000
# Class 4 (Speed limit 70): 0.0000
# Class 5 (Speed limit 80): 0.0000
# Class 6 (End of speed limit 80): 0.0000
# Class 7 (Speed limit 100): 0.0008
# Class 8 (Speed limit 120): 0.0001
# Class 9 (No passing): 0.3748
# Class 10 (No passing for vehicles over 3.5 tons): 0.0001
# Class 11 (Right-of-way at next intersection): 0.0000
# Class 12 (Priority road): 0.0003
# Class 13 (Yield): 0.0381
# Class 14 (Stop): 0.0011
# Class 15 (No vehicles): 0.0001
# Class 16 (Vehicles over 3.5 tons prohibited): 0.0471
# Class 17 (No entry): 0.0028
# Class 18 (General caution): 0.0007
# Class 19 (Dangerous curve left): 0.0000
# Class 20 (Dangerous curve right): 0.0001
# Class 21 (Double curve): 0.0000
# Class 22 (Bumpy road): 0.0000
# Class 23 (Slippery road): 0.1361
# Class 24 (Road narrows on the right): 0.0000
# Class 25 (Road work): 0.0000
# Class 26 (Traffic signals): 0.0002
# Class 27 (Pedestrians): 0.0002
# Class 28 (Children crossing): 0.0001
# Class 29 (Bicycles crossing): 0.0000
# Class 30 (Beware of ice/snow): 0.0000
# Class 31 (Wild animals crossing): 0.0000
# Class 32 (End of all speed and passing limits): 0.0004
# Class 33 (Turn right ahead): 0.0000
# Class 34 (Turn left ahead): 0.0000
# Class 35 (Ahead only): 0.0000
# Class 36 (Go straight or right): 0.0013
# Class 37 (Go straight or left): 0.0000
# Class 38 (Keep right): 0.0000
# Class 39 (Keep left): 0.0000
# Class 40 (Roundabout mandatory): 0.0000
# Class 41 (End of no passing): 0.3940
# Class 42 (End of no passing for vehicles over 3.5 tons): 0.0015
# Predicted class: End of no passing
# np.int64(41)

# %% [markdown]
# ***First Adverserial Example***

# %%
# Example usage:
image_path = "Restricted.ppm"
model = tf.keras.models.load_model("TrafficSigns_EfficientNetB1.keras")  # Load your trained model
image_tensor = load_ppm_image(image_path, target_size=(240, 240))
true_label = predict_traffic_sign(image_tensor, model, GTSRB_CLASSES)
adv_image_tensor = simba_attack(image_tensor, true_label, model, num_iters=100, epsilon=0.2, print_every=10)
#
# # Optionally, save or visualize the adversarial image:
adv_image = adv_image_tensor.numpy()[0].astype(np.uint8)
adv_pil = Image.fromarray(adv_image)
adv_pil.save("Restriction_adv_image.ppm")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# Prediction shape: (1, 43)
# Predicted class: End of no passing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 915ms/step
# Initial true class probability for label 41: 0.3940
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 0: -epsilon -> pixel=(139,92,2), old_prob=0.393962, new_prob=0.392702, diff=-0.001260
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# Iteration 1: +epsilon -> pixel=(59,78,0), old_prob=0.392702, new_prob=0.392470, diff=-0.000232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2: -epsilon -> pixel=(164,218,2), old_prob=0.392470, new_prob=0.391060, diff=-0.001410
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 900ms/step
# Iteration 3: +epsilon -> pixel=(8,107,2), old_prob=0.391060, new_prob=0.391025, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 4: -epsilon -> pixel=(8,153,2), old_prob=0.391025, new_prob=0.391003, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 895ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# Iteration 5: -epsilon -> pixel=(105,46,2), old_prob=0.391003, new_prob=0.390809, diff=-0.000194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 6: +epsilon -> pixel=(81,120,0), old_prob=0.390809, new_prob=0.390477, diff=-0.000333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 897ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 8: -epsilon -> pixel=(203,138,2), old_prob=0.390477, new_prob=0.390162, diff=-0.000315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 9: +epsilon -> pixel=(52,6,2), old_prob=0.390162, new_prob=0.390109, diff=-0.000053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 889ms/step
# Iteration 10: +epsilon -> pixel=(60,180,0), old_prob=0.390109, new_prob=0.389264, diff=-0.000845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 878ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# Iteration 11: -epsilon -> pixel=(47,38,1), old_prob=0.389264, new_prob=0.389183, diff=-0.000081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 895ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# Iteration 12: +epsilon -> pixel=(190,225,2), old_prob=0.389183, new_prob=0.389173, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 13: -epsilon -> pixel=(170,237,2), old_prob=0.389173, new_prob=0.389034, diff=-0.000139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 881ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# Iteration 14: -epsilon -> pixel=(143,207,1), old_prob=0.389034, new_prob=0.387731, diff=-0.001303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step
# Iteration 15: +epsilon -> pixel=(230,19,1), old_prob=0.387731, new_prob=0.387726, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# Iteration 16: +epsilon -> pixel=(121,190,0), old_prob=0.387726, new_prob=0.384929, diff=-0.002798
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step
# Attack successful at iteration 16: predicted class flipped to 9 != true label 41
# Attack finished after 17 iterations. Final true class probability: 0.3849

# %%
adverserial_image_path = "/content/Restriction_adv_image.ppm"
# Load and preprocess the image with the correct target size (240x240)
image = load_ppm_image(adverserial_image_path, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign_all(image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Prediction shape: (1, 43)
# Class 0 (Speed limit 20): 0.0000
# Class 1 (Speed limit 30): 0.0000
# Class 2 (Speed limit 50): 0.0000
# Class 3 (Speed limit 60): 0.0000
# Class 4 (Speed limit 70): 0.0000
# Class 5 (Speed limit 80): 0.0000
# Class 6 (End of speed limit 80): 0.0000
# Class 7 (Speed limit 100): 0.0008
# Class 8 (Speed limit 120): 0.0001
# Class 9 (No passing): 0.3859
# Class 10 (No passing for vehicles over 3.5 tons): 0.0001
# Class 11 (Right-of-way at next intersection): 0.0000
# Class 12 (Priority road): 0.0003
# Class 13 (Yield): 0.0383
# Class 14 (Stop): 0.0011
# Class 15 (No vehicles): 0.0001
# Class 16 (Vehicles over 3.5 tons prohibited): 0.0475
# Class 17 (No entry): 0.0027
# Class 18 (General caution): 0.0007
# Class 19 (Dangerous curve left): 0.0000
# Class 20 (Dangerous curve right): 0.0001
# Class 21 (Double curve): 0.0000
# Class 22 (Bumpy road): 0.0000
# Class 23 (Slippery road): 0.1335
# Class 24 (Road narrows on the right): 0.0000
# Class 25 (Road work): 0.0000
# Class 26 (Traffic signals): 0.0002
# Class 27 (Pedestrians): 0.0002
# Class 28 (Children crossing): 0.0001
# Class 29 (Bicycles crossing): 0.0000
# Class 30 (Beware of ice/snow): 0.0000
# Class 31 (Wild animals crossing): 0.0000
# Class 32 (End of all speed and passing limits): 0.0004
# Class 33 (Turn right ahead): 0.0000
# Class 34 (Turn left ahead): 0.0000
# Class 35 (Ahead only): 0.0000
# Class 36 (Go straight or right): 0.0012
# Class 37 (Go straight or left): 0.0000
# Class 38 (Keep right): 0.0000
# Class 39 (Keep left): 0.0000
# Class 40 (Roundabout mandatory): 0.0000
# Class 41 (End of no passing): 0.3849
# Class 42 (End of no passing for vehicles over 3.5 tons): 0.0015
# Predicted class: No passing
# np.int64(9)

# %%
display_ppm_image(adverserial_image_path)

# %% [markdown]
# ***Second Adverserial Example***

# %%
# Example usage:
image_path = "ppm_limit20.ppm"
model = tf.keras.models.load_model("TrafficSigns_EfficientNetB1.keras")  # Load your trained model
image_tensor = load_ppm_image(image_path, target_size=(240, 240))
true_label = predict_traffic_sign(image_tensor, model, GTSRB_CLASSES)
adv_image_tensor = simba_attack(image_tensor, true_label, model, num_iters=2000, epsilon=0.2, print_every=10)
#
# # Optionally, save or visualize the adversarial image:
adv_image = adv_image_tensor.numpy()[0].astype(np.uint8)
adv_pil = Image.fromarray(adv_image)
adv_pil.save("adv_image.ppm")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# Prediction shape: (1, 43)
# Predicted class: Speed limit 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Initial true class probability: 0.9749
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 0: +epsilon -> pixel=(68,223,0), old_prob=0.974873, new_prob=0.974873, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1: -epsilon -> pixel=(39,234,0), old_prob=0.974873, new_prob=0.974866, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2: +epsilon -> pixel=(210,34,2), old_prob=0.974866, new_prob=0.974862, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 3: +epsilon -> pixel=(51,76,1), old_prob=0.974862, new_prob=0.974828, diff=-0.000033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 4: -epsilon -> pixel=(55,146,0), old_prob=0.974828, new_prob=0.974700, diff=-0.000128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 5: -epsilon -> pixel=(47,105,1), old_prob=0.974700, new_prob=0.974621, diff=-0.000080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# Iteration 6: -epsilon -> pixel=(119,235,2), old_prob=0.974621, new_prob=0.974617, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 7: +epsilon -> pixel=(125,210,1), old_prob=0.974617, new_prob=0.974606, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 8: -epsilon -> pixel=(35,81,2), old_prob=0.974606, new_prob=0.974548, diff=-0.000058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 9: -epsilon -> pixel=(216,95,0), old_prob=0.974548, new_prob=0.974531, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 10: -epsilon -> pixel=(211,184,0), old_prob=0.974531, new_prob=0.974530, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Iteration 11: +epsilon -> pixel=(34,69,1), old_prob=0.974530, new_prob=0.974526, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# Iteration 12: +epsilon -> pixel=(190,19,1), old_prob=0.974526, new_prob=0.974518, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 13: -epsilon -> pixel=(34,200,1), old_prob=0.974518, new_prob=0.974488, diff=-0.000030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 14: +epsilon -> pixel=(229,5,0), old_prob=0.974488, new_prob=0.974487, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 15: +epsilon -> pixel=(169,101,2), old_prob=0.974487, new_prob=0.974482, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 16: -epsilon -> pixel=(67,40,1), old_prob=0.974482, new_prob=0.974445, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 17: +epsilon -> pixel=(104,71,1), old_prob=0.974445, new_prob=0.974444, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 18: -epsilon -> pixel=(105,35,2), old_prob=0.974444, new_prob=0.974438, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 19: -epsilon -> pixel=(151,84,0), old_prob=0.974438, new_prob=0.974437, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 20: -epsilon -> pixel=(125,26,2), old_prob=0.974437, new_prob=0.974431, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# Iteration 21: +epsilon -> pixel=(88,106,1), old_prob=0.974431, new_prob=0.974413, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 22: +epsilon -> pixel=(141,139,1), old_prob=0.974413, new_prob=0.974399, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 23: +epsilon -> pixel=(224,202,0), old_prob=0.974399, new_prob=0.974366, diff=-0.000033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 24: -epsilon -> pixel=(153,159,2), old_prob=0.974366, new_prob=0.974282, diff=-0.000085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 25: +epsilon -> pixel=(18,18,2), old_prob=0.974282, new_prob=0.974279, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 26: -epsilon -> pixel=(55,105,0), old_prob=0.974279, new_prob=0.974227, diff=-0.000052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 27: -epsilon -> pixel=(231,85,2), old_prob=0.974227, new_prob=0.974226, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# Iteration 28: -epsilon -> pixel=(215,140,2), old_prob=0.974226, new_prob=0.974216, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# Iteration 29: +epsilon -> pixel=(47,96,2), old_prob=0.974216, new_prob=0.974197, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# Iteration 30: -epsilon -> pixel=(198,19,2), old_prob=0.974197, new_prob=0.974194, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 31: -epsilon -> pixel=(179,51,1), old_prob=0.974194, new_prob=0.974193, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 32: -epsilon -> pixel=(109,77,0), old_prob=0.974193, new_prob=0.974160, diff=-0.000033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 33: -epsilon -> pixel=(183,13,2), old_prob=0.974160, new_prob=0.974152, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 903ms/step
# Iteration 34: -epsilon -> pixel=(134,188,2), old_prob=0.974152, new_prob=0.974060, diff=-0.000092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 35: +epsilon -> pixel=(186,177,2), old_prob=0.974060, new_prob=0.974049, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 36: -epsilon -> pixel=(9,224,1), old_prob=0.974049, new_prob=0.974045, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 37: +epsilon -> pixel=(191,222,2), old_prob=0.974045, new_prob=0.974043, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 38: -epsilon -> pixel=(22,52,2), old_prob=0.974043, new_prob=0.974043, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 39: +epsilon -> pixel=(210,47,2), old_prob=0.974043, new_prob=0.973997, diff=-0.000046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# Iteration 40: +epsilon -> pixel=(91,78,0), old_prob=0.973997, new_prob=0.973944, diff=-0.000053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 41: +epsilon -> pixel=(5,102,0), old_prob=0.973944, new_prob=0.973943, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# Iteration 42: -epsilon -> pixel=(132,179,2), old_prob=0.973943, new_prob=0.973924, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 907ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 43: -epsilon -> pixel=(10,10,0), old_prob=0.973924, new_prob=0.973921, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 44: +epsilon -> pixel=(171,124,0), old_prob=0.973921, new_prob=0.973903, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 45: +epsilon -> pixel=(150,159,0), old_prob=0.973903, new_prob=0.973776, diff=-0.000127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# Iteration 46: -epsilon -> pixel=(67,238,1), old_prob=0.973776, new_prob=0.973772, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# Iteration 47: +epsilon -> pixel=(31,67,2), old_prob=0.973772, new_prob=0.973767, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 915ms/step
# Iteration 48: -epsilon -> pixel=(87,155,1), old_prob=0.973767, new_prob=0.973678, diff=-0.000089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 49: +epsilon -> pixel=(222,159,2), old_prob=0.973678, new_prob=0.973673, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 50: -epsilon -> pixel=(122,15,1), old_prob=0.973673, new_prob=0.973668, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 51: +epsilon -> pixel=(38,183,1), old_prob=0.973668, new_prob=0.973535, diff=-0.000133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 52: +epsilon -> pixel=(129,0,2), old_prob=0.973535, new_prob=0.973535, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 53: -epsilon -> pixel=(145,211,2), old_prob=0.973535, new_prob=0.973533, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 54: -epsilon -> pixel=(123,153,2), old_prob=0.973533, new_prob=0.973458, diff=-0.000075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 55: +epsilon -> pixel=(1,1,1), old_prob=0.973458, new_prob=0.973458, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 56: +epsilon -> pixel=(239,231,0), old_prob=0.973458, new_prob=0.973457, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 907ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 58: +epsilon -> pixel=(154,161,0), old_prob=0.973457, new_prob=0.973436, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 59: +epsilon -> pixel=(149,180,1), old_prob=0.973436, new_prob=0.973426, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 60: -epsilon -> pixel=(8,137,0), old_prob=0.973426, new_prob=0.973421, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 62: +epsilon -> pixel=(66,28,0), old_prob=0.973421, new_prob=0.973378, diff=-0.000043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Iteration 63: -epsilon -> pixel=(101,235,0), old_prob=0.973378, new_prob=0.973373, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# Iteration 64: +epsilon -> pixel=(119,239,0), old_prob=0.973373, new_prob=0.973366, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 65: +epsilon -> pixel=(146,216,0), old_prob=0.973366, new_prob=0.973334, diff=-0.000032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 66: +epsilon -> pixel=(214,36,0), old_prob=0.973334, new_prob=0.973319, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 67: +epsilon -> pixel=(95,205,1), old_prob=0.973319, new_prob=0.973308, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 68: +epsilon -> pixel=(172,111,0), old_prob=0.973308, new_prob=0.973192, diff=-0.000116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 69: +epsilon -> pixel=(220,17,1), old_prob=0.973192, new_prob=0.973188, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 70: +epsilon -> pixel=(98,26,2), old_prob=0.973188, new_prob=0.973172, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Iteration 71: -epsilon -> pixel=(57,22,0), old_prob=0.973172, new_prob=0.973159, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 73: -epsilon -> pixel=(102,166,0), old_prob=0.973159, new_prob=0.972591, diff=-0.000568
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# Iteration 74: -epsilon -> pixel=(185,160,1), old_prob=0.972591, new_prob=0.972563, diff=-0.000028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# Iteration 75: -epsilon -> pixel=(184,120,1), old_prob=0.972563, new_prob=0.972507, diff=-0.000057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 76: +epsilon -> pixel=(234,239,1), old_prob=0.972507, new_prob=0.972504, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 77: -epsilon -> pixel=(234,54,2), old_prob=0.972504, new_prob=0.972479, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 79: +epsilon -> pixel=(175,114,2), old_prob=0.972479, new_prob=0.972445, diff=-0.000035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 80: +epsilon -> pixel=(220,161,2), old_prob=0.972445, new_prob=0.972437, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 81: -epsilon -> pixel=(143,170,2), old_prob=0.972437, new_prob=0.972383, diff=-0.000054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 82: +epsilon -> pixel=(24,228,0), old_prob=0.972383, new_prob=0.972374, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 83: -epsilon -> pixel=(83,129,1), old_prob=0.972374, new_prob=0.972084, diff=-0.000290
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 84: +epsilon -> pixel=(14,114,1), old_prob=0.972084, new_prob=0.972081, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 85: +epsilon -> pixel=(203,150,1), old_prob=0.972081, new_prob=0.972055, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 902ms/step
# Iteration 86: -epsilon -> pixel=(51,6,2), old_prob=0.972055, new_prob=0.972054, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 88: -epsilon -> pixel=(189,185,0), old_prob=0.972054, new_prob=0.972052, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# Iteration 89: +epsilon -> pixel=(133,196,0), old_prob=0.972052, new_prob=0.972032, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 90: -epsilon -> pixel=(15,87,0), old_prob=0.972032, new_prob=0.972025, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 91: -epsilon -> pixel=(223,103,0), old_prob=0.972025, new_prob=0.971997, diff=-0.000029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 92: +epsilon -> pixel=(77,209,2), old_prob=0.971997, new_prob=0.971973, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 94: -epsilon -> pixel=(18,69,1), old_prob=0.971973, new_prob=0.971968, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 95: -epsilon -> pixel=(67,131,0), old_prob=0.971968, new_prob=0.971863, diff=-0.000105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 96: +epsilon -> pixel=(0,121,0), old_prob=0.971863, new_prob=0.971856, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 97: -epsilon -> pixel=(15,80,2), old_prob=0.971856, new_prob=0.971851, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# Iteration 98: +epsilon -> pixel=(169,209,1), old_prob=0.971851, new_prob=0.971827, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 99: +epsilon -> pixel=(233,33,0), old_prob=0.971827, new_prob=0.971822, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 100: +epsilon -> pixel=(211,223,1), old_prob=0.971822, new_prob=0.971816, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 101: -epsilon -> pixel=(4,2,0), old_prob=0.971816, new_prob=0.971816, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 102: +epsilon -> pixel=(214,146,1), old_prob=0.971816, new_prob=0.971807, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Iteration 103: -epsilon -> pixel=(85,10,2), old_prob=0.971807, new_prob=0.971803, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 104: -epsilon -> pixel=(117,137,2), old_prob=0.971803, new_prob=0.971735, diff=-0.000068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 105: -epsilon -> pixel=(150,193,2), old_prob=0.971735, new_prob=0.971704, diff=-0.000032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# Iteration 106: +epsilon -> pixel=(150,96,2), old_prob=0.971704, new_prob=0.971666, diff=-0.000038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 108: -epsilon -> pixel=(191,52,0), old_prob=0.971666, new_prob=0.971650, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 109: -epsilon -> pixel=(204,36,2), old_prob=0.971650, new_prob=0.971637, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 110: -epsilon -> pixel=(20,202,2), old_prob=0.971637, new_prob=0.971589, diff=-0.000048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 111: +epsilon -> pixel=(21,229,0), old_prob=0.971589, new_prob=0.971586, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 112: -epsilon -> pixel=(17,128,1), old_prob=0.971586, new_prob=0.971576, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 113: -epsilon -> pixel=(74,44,0), old_prob=0.971576, new_prob=0.971485, diff=-0.000091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 114: -epsilon -> pixel=(114,86,0), old_prob=0.971485, new_prob=0.971448, diff=-0.000037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 115: +epsilon -> pixel=(194,211,1), old_prob=0.971448, new_prob=0.971434, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 116: +epsilon -> pixel=(233,66,1), old_prob=0.971434, new_prob=0.971420, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 117: +epsilon -> pixel=(113,72,2), old_prob=0.971420, new_prob=0.971375, diff=-0.000045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 118: +epsilon -> pixel=(126,128,0), old_prob=0.971375, new_prob=0.971295, diff=-0.000080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 119: -epsilon -> pixel=(66,234,0), old_prob=0.971295, new_prob=0.971270, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 120: -epsilon -> pixel=(188,210,2), old_prob=0.971270, new_prob=0.971266, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 121: +epsilon -> pixel=(202,215,2), old_prob=0.971266, new_prob=0.971253, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 122: +epsilon -> pixel=(33,182,1), old_prob=0.971253, new_prob=0.971198, diff=-0.000056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 123: -epsilon -> pixel=(210,149,1), old_prob=0.971198, new_prob=0.971193, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 124: +epsilon -> pixel=(128,160,1), old_prob=0.971193, new_prob=0.970943, diff=-0.000250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 125: -epsilon -> pixel=(147,80,1), old_prob=0.970943, new_prob=0.970937, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 126: -epsilon -> pixel=(54,22,0), old_prob=0.970937, new_prob=0.970893, diff=-0.000044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 127: -epsilon -> pixel=(199,197,0), old_prob=0.970893, new_prob=0.970871, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Iteration 128: -epsilon -> pixel=(172,211,1), old_prob=0.970871, new_prob=0.970854, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# Iteration 129: +epsilon -> pixel=(164,219,0), old_prob=0.970854, new_prob=0.970809, diff=-0.000045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 130: +epsilon -> pixel=(44,69,2), old_prob=0.970809, new_prob=0.970797, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# Iteration 131: -epsilon -> pixel=(12,92,2), old_prob=0.970797, new_prob=0.970775, diff=-0.000023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 132: +epsilon -> pixel=(17,198,1), old_prob=0.970775, new_prob=0.970770, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# Iteration 133: -epsilon -> pixel=(234,149,0), old_prob=0.970770, new_prob=0.970766, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 134: +epsilon -> pixel=(138,17,0), old_prob=0.970766, new_prob=0.970751, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 135: -epsilon -> pixel=(154,2,0), old_prob=0.970751, new_prob=0.970745, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 136: +epsilon -> pixel=(5,205,2), old_prob=0.970745, new_prob=0.970744, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 137: -epsilon -> pixel=(68,49,1), old_prob=0.970744, new_prob=0.970723, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 138: +epsilon -> pixel=(133,18,0), old_prob=0.970723, new_prob=0.970712, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 139: +epsilon -> pixel=(79,163,1), old_prob=0.970712, new_prob=0.970677, diff=-0.000035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 140: +epsilon -> pixel=(206,234,2), old_prob=0.970677, new_prob=0.970670, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 141: +epsilon -> pixel=(17,163,1), old_prob=0.970670, new_prob=0.970652, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 142: -epsilon -> pixel=(230,199,0), old_prob=0.970652, new_prob=0.970625, diff=-0.000027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# Iteration 143: -epsilon -> pixel=(121,236,1), old_prob=0.970625, new_prob=0.970622, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 144: +epsilon -> pixel=(225,19,0), old_prob=0.970622, new_prob=0.970618, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# Iteration 145: +epsilon -> pixel=(209,119,0), old_prob=0.970618, new_prob=0.970611, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 147: +epsilon -> pixel=(151,133,0), old_prob=0.970611, new_prob=0.970605, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# Iteration 148: +epsilon -> pixel=(232,129,0), old_prob=0.970605, new_prob=0.970602, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 149: -epsilon -> pixel=(171,113,2), old_prob=0.970602, new_prob=0.970578, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 150: -epsilon -> pixel=(188,72,1), old_prob=0.970578, new_prob=0.970564, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 151: +epsilon -> pixel=(64,89,1), old_prob=0.970564, new_prob=0.970556, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# Iteration 153: +epsilon -> pixel=(51,183,1), old_prob=0.970556, new_prob=0.970529, diff=-0.000027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 154: +epsilon -> pixel=(222,62,2), old_prob=0.970529, new_prob=0.970516, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 155: +epsilon -> pixel=(75,3,2), old_prob=0.970516, new_prob=0.970515, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# Iteration 157: +epsilon -> pixel=(91,164,1), old_prob=0.970515, new_prob=0.970462, diff=-0.000053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 158: -epsilon -> pixel=(3,14,1), old_prob=0.970462, new_prob=0.970461, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 159: +epsilon -> pixel=(164,85,2), old_prob=0.970461, new_prob=0.970425, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# Iteration 160: +epsilon -> pixel=(38,190,0), old_prob=0.970425, new_prob=0.970413, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 161: +epsilon -> pixel=(34,158,2), old_prob=0.970413, new_prob=0.970405, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 162: -epsilon -> pixel=(155,90,0), old_prob=0.970405, new_prob=0.970386, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 163: -epsilon -> pixel=(110,90,0), old_prob=0.970386, new_prob=0.970301, diff=-0.000085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 164: +epsilon -> pixel=(88,203,2), old_prob=0.970301, new_prob=0.970197, diff=-0.000104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# Iteration 165: +epsilon -> pixel=(207,71,1), old_prob=0.970197, new_prob=0.970183, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 166: +epsilon -> pixel=(111,128,2), old_prob=0.970183, new_prob=0.970118, diff=-0.000066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# Iteration 167: -epsilon -> pixel=(215,190,0), old_prob=0.970118, new_prob=0.970108, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 168: -epsilon -> pixel=(15,163,2), old_prob=0.970108, new_prob=0.970104, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 169: -epsilon -> pixel=(42,111,1), old_prob=0.970104, new_prob=0.970066, diff=-0.000039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 170: -epsilon -> pixel=(112,149,1), old_prob=0.970066, new_prob=0.969920, diff=-0.000146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 171: -epsilon -> pixel=(32,55,2), old_prob=0.969920, new_prob=0.969919, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# Iteration 172: +epsilon -> pixel=(114,38,0), old_prob=0.969919, new_prob=0.969907, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 173: +epsilon -> pixel=(183,25,0), old_prob=0.969907, new_prob=0.969899, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 174: +epsilon -> pixel=(3,42,2), old_prob=0.969899, new_prob=0.969895, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 175: -epsilon -> pixel=(168,31,0), old_prob=0.969895, new_prob=0.969882, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 176: +epsilon -> pixel=(65,172,0), old_prob=0.969882, new_prob=0.969792, diff=-0.000090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 177: -epsilon -> pixel=(177,187,2), old_prob=0.969792, new_prob=0.969791, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 178: -epsilon -> pixel=(26,140,2), old_prob=0.969791, new_prob=0.969766, diff=-0.000025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 179: +epsilon -> pixel=(15,224,1), old_prob=0.969766, new_prob=0.969760, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# Iteration 180: -epsilon -> pixel=(204,12,0), old_prob=0.969760, new_prob=0.969746, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 181: -epsilon -> pixel=(16,43,0), old_prob=0.969746, new_prob=0.969738, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 182: +epsilon -> pixel=(96,213,2), old_prob=0.969738, new_prob=0.969728, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 183: +epsilon -> pixel=(123,154,1), old_prob=0.969728, new_prob=0.969669, diff=-0.000059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# Iteration 184: -epsilon -> pixel=(144,11,1), old_prob=0.969669, new_prob=0.969666, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# Iteration 185: +epsilon -> pixel=(239,8,0), old_prob=0.969666, new_prob=0.969666, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# Iteration 186: +epsilon -> pixel=(179,127,1), old_prob=0.969666, new_prob=0.969648, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# Iteration 187: -epsilon -> pixel=(114,196,2), old_prob=0.969648, new_prob=0.969580, diff=-0.000067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# Iteration 188: +epsilon -> pixel=(39,126,2), old_prob=0.969580, new_prob=0.969561, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 189: +epsilon -> pixel=(50,205,1), old_prob=0.969561, new_prob=0.969523, diff=-0.000038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 190: +epsilon -> pixel=(23,183,2), old_prob=0.969523, new_prob=0.969507, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 191: +epsilon -> pixel=(80,33,1), old_prob=0.969507, new_prob=0.969506, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 192: +epsilon -> pixel=(194,154,2), old_prob=0.969506, new_prob=0.969496, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 193: -epsilon -> pixel=(117,100,0), old_prob=0.969496, new_prob=0.969469, diff=-0.000027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 194: +epsilon -> pixel=(53,229,1), old_prob=0.969469, new_prob=0.969467, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 195: -epsilon -> pixel=(225,33,2), old_prob=0.969467, new_prob=0.969465, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 196: +epsilon -> pixel=(156,56,0), old_prob=0.969465, new_prob=0.969424, diff=-0.000042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 197: +epsilon -> pixel=(4,68,1), old_prob=0.969424, new_prob=0.969401, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 199: -epsilon -> pixel=(173,216,0), old_prob=0.969401, new_prob=0.969375, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 200: -epsilon -> pixel=(177,55,0), old_prob=0.969375, new_prob=0.969373, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# Iteration 201: -epsilon -> pixel=(56,164,2), old_prob=0.969373, new_prob=0.969362, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 202: +epsilon -> pixel=(163,41,1), old_prob=0.969362, new_prob=0.969362, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 203: -epsilon -> pixel=(82,138,2), old_prob=0.969362, new_prob=0.968935, diff=-0.000427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# Iteration 204: +epsilon -> pixel=(15,96,0), old_prob=0.968935, new_prob=0.968921, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# Iteration 205: +epsilon -> pixel=(73,64,0), old_prob=0.968921, new_prob=0.968916, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 206: -epsilon -> pixel=(150,104,1), old_prob=0.968916, new_prob=0.968859, diff=-0.000057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 208: -epsilon -> pixel=(121,140,2), old_prob=0.968859, new_prob=0.968635, diff=-0.000224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 209: +epsilon -> pixel=(42,134,1), old_prob=0.968635, new_prob=0.968597, diff=-0.000037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 210: +epsilon -> pixel=(30,120,2), old_prob=0.968597, new_prob=0.968584, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Iteration 211: -epsilon -> pixel=(63,52,0), old_prob=0.968584, new_prob=0.968569, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 212: +epsilon -> pixel=(152,213,1), old_prob=0.968569, new_prob=0.968531, diff=-0.000038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# Iteration 213: +epsilon -> pixel=(70,58,1), old_prob=0.968531, new_prob=0.968515, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 214: +epsilon -> pixel=(140,30,0), old_prob=0.968515, new_prob=0.968475, diff=-0.000040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 215: -epsilon -> pixel=(235,18,2), old_prob=0.968475, new_prob=0.968466, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 216: +epsilon -> pixel=(52,82,1), old_prob=0.968466, new_prob=0.968461, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 217: -epsilon -> pixel=(138,145,1), old_prob=0.968461, new_prob=0.968458, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 218: +epsilon -> pixel=(20,27,2), old_prob=0.968458, new_prob=0.968456, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 219: +epsilon -> pixel=(204,105,2), old_prob=0.968456, new_prob=0.968442, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 220: -epsilon -> pixel=(228,112,2), old_prob=0.968442, new_prob=0.968434, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# Iteration 221: +epsilon -> pixel=(155,119,2), old_prob=0.968434, new_prob=0.968425, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 222: +epsilon -> pixel=(25,88,0), old_prob=0.968425, new_prob=0.968413, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 223: -epsilon -> pixel=(213,161,2), old_prob=0.968413, new_prob=0.968405, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 224: +epsilon -> pixel=(220,209,0), old_prob=0.968405, new_prob=0.968394, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# Iteration 225: +epsilon -> pixel=(125,171,0), old_prob=0.968394, new_prob=0.968334, diff=-0.000060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# Iteration 226: +epsilon -> pixel=(106,193,2), old_prob=0.968334, new_prob=0.968242, diff=-0.000092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Iteration 227: +epsilon -> pixel=(2,121,1), old_prob=0.968242, new_prob=0.968231, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# Iteration 228: -epsilon -> pixel=(171,47,2), old_prob=0.968231, new_prob=0.968228, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 229: -epsilon -> pixel=(140,4,0), old_prob=0.968228, new_prob=0.968226, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# Iteration 230: -epsilon -> pixel=(182,225,0), old_prob=0.968226, new_prob=0.968209, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 231: -epsilon -> pixel=(237,236,1), old_prob=0.968209, new_prob=0.968208, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 232: +epsilon -> pixel=(33,125,1), old_prob=0.968208, new_prob=0.968184, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 234: -epsilon -> pixel=(179,95,0), old_prob=0.968184, new_prob=0.968172, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 235: +epsilon -> pixel=(83,226,2), old_prob=0.968172, new_prob=0.968156, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# Iteration 236: +epsilon -> pixel=(207,31,1), old_prob=0.968156, new_prob=0.968144, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 237: +epsilon -> pixel=(133,72,1), old_prob=0.968144, new_prob=0.968117, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 238: +epsilon -> pixel=(219,144,0), old_prob=0.968117, new_prob=0.968116, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# Iteration 239: -epsilon -> pixel=(191,119,0), old_prob=0.968116, new_prob=0.968096, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 240: -epsilon -> pixel=(67,4,0), old_prob=0.968096, new_prob=0.968094, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# Iteration 241: -epsilon -> pixel=(105,116,1), old_prob=0.968094, new_prob=0.966954, diff=-0.001140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 242: -epsilon -> pixel=(191,125,0), old_prob=0.966954, new_prob=0.966948, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 243: +epsilon -> pixel=(61,16,2), old_prob=0.966948, new_prob=0.966940, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 244: +epsilon -> pixel=(233,78,1), old_prob=0.966940, new_prob=0.966935, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 245: +epsilon -> pixel=(85,106,1), old_prob=0.966935, new_prob=0.966920, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# Iteration 246: +epsilon -> pixel=(16,106,0), old_prob=0.966920, new_prob=0.966907, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 247: -epsilon -> pixel=(44,2,1), old_prob=0.966907, new_prob=0.966893, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# Iteration 248: -epsilon -> pixel=(230,16,0), old_prob=0.966893, new_prob=0.966880, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# Iteration 249: +epsilon -> pixel=(3,193,1), old_prob=0.966880, new_prob=0.966879, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 250: -epsilon -> pixel=(65,75,0), old_prob=0.966879, new_prob=0.966835, diff=-0.000044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 251: +epsilon -> pixel=(230,56,1), old_prob=0.966835, new_prob=0.966834, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# Iteration 252: +epsilon -> pixel=(166,147,1), old_prob=0.966834, new_prob=0.966830, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 253: +epsilon -> pixel=(137,142,2), old_prob=0.966830, new_prob=0.966826, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 254: -epsilon -> pixel=(108,54,1), old_prob=0.966826, new_prob=0.966805, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 255: +epsilon -> pixel=(19,16,0), old_prob=0.966805, new_prob=0.966804, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 256: +epsilon -> pixel=(171,146,1), old_prob=0.966804, new_prob=0.966693, diff=-0.000110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 257: +epsilon -> pixel=(145,3,2), old_prob=0.966693, new_prob=0.966693, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 258: -epsilon -> pixel=(95,47,1), old_prob=0.966693, new_prob=0.966678, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 259: +epsilon -> pixel=(120,70,2), old_prob=0.966678, new_prob=0.966587, diff=-0.000091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 260: +epsilon -> pixel=(144,119,2), old_prob=0.966587, new_prob=0.966548, diff=-0.000038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 261: -epsilon -> pixel=(138,198,1), old_prob=0.966548, new_prob=0.966199, diff=-0.000349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 262: +epsilon -> pixel=(47,167,1), old_prob=0.966199, new_prob=0.966138, diff=-0.000061
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# Iteration 263: +epsilon -> pixel=(93,119,0), old_prob=0.966138, new_prob=0.966120, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Iteration 265: +epsilon -> pixel=(217,64,2), old_prob=0.966120, new_prob=0.966115, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 266: -epsilon -> pixel=(159,107,1), old_prob=0.966115, new_prob=0.966095, diff=-0.000020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 267: -epsilon -> pixel=(144,151,1), old_prob=0.966095, new_prob=0.966031, diff=-0.000064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 268: -epsilon -> pixel=(30,178,0), old_prob=0.966031, new_prob=0.965946, diff=-0.000085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 269: -epsilon -> pixel=(17,101,2), old_prob=0.965946, new_prob=0.965937, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Iteration 270: -epsilon -> pixel=(185,221,1), old_prob=0.965937, new_prob=0.965926, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 271: -epsilon -> pixel=(38,167,2), old_prob=0.965926, new_prob=0.965920, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 272: +epsilon -> pixel=(116,58,1), old_prob=0.965920, new_prob=0.965807, diff=-0.000113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 273: -epsilon -> pixel=(196,114,0), old_prob=0.965807, new_prob=0.965760, diff=-0.000047
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# Iteration 274: +epsilon -> pixel=(125,165,0), old_prob=0.965760, new_prob=0.965759, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 275: +epsilon -> pixel=(50,79,0), old_prob=0.965759, new_prob=0.965718, diff=-0.000041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# Iteration 276: -epsilon -> pixel=(180,226,2), old_prob=0.965718, new_prob=0.965662, diff=-0.000056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# Iteration 277: +epsilon -> pixel=(32,50,2), old_prob=0.965662, new_prob=0.965662, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# Iteration 278: +epsilon -> pixel=(88,134,1), old_prob=0.965662, new_prob=0.965396, diff=-0.000266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 279: -epsilon -> pixel=(171,22,2), old_prob=0.965396, new_prob=0.965389, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 280: +epsilon -> pixel=(195,98,2), old_prob=0.965389, new_prob=0.965376, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 282: +epsilon -> pixel=(237,168,0), old_prob=0.965376, new_prob=0.965371, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 283: -epsilon -> pixel=(194,189,1), old_prob=0.965371, new_prob=0.965369, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 284: -epsilon -> pixel=(217,89,0), old_prob=0.965369, new_prob=0.965360, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 285: +epsilon -> pixel=(148,225,2), old_prob=0.965360, new_prob=0.965349, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 286: +epsilon -> pixel=(8,200,1), old_prob=0.965349, new_prob=0.965333, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 288: -epsilon -> pixel=(233,146,1), old_prob=0.965333, new_prob=0.965331, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 289: -epsilon -> pixel=(20,144,1), old_prob=0.965331, new_prob=0.965322, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Iteration 290: +epsilon -> pixel=(32,229,1), old_prob=0.965322, new_prob=0.965312, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 291: -epsilon -> pixel=(149,171,1), old_prob=0.965312, new_prob=0.965292, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 292: +epsilon -> pixel=(136,222,1), old_prob=0.965292, new_prob=0.965284, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 293: -epsilon -> pixel=(157,122,2), old_prob=0.965284, new_prob=0.965274, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 294: +epsilon -> pixel=(54,150,2), old_prob=0.965274, new_prob=0.965266, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# Iteration 295: +epsilon -> pixel=(98,147,2), old_prob=0.965266, new_prob=0.965216, diff=-0.000050
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 296: +epsilon -> pixel=(31,1,2), old_prob=0.965216, new_prob=0.965214, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 297: +epsilon -> pixel=(161,91,2), old_prob=0.965214, new_prob=0.965194, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 298: +epsilon -> pixel=(5,92,2), old_prob=0.965194, new_prob=0.965191, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 299: -epsilon -> pixel=(72,204,0), old_prob=0.965191, new_prob=0.964894, diff=-0.000298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 300: -epsilon -> pixel=(209,99,1), old_prob=0.964894, new_prob=0.964874, diff=-0.000020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 301: -epsilon -> pixel=(165,98,2), old_prob=0.964874, new_prob=0.964848, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 302: +epsilon -> pixel=(94,132,2), old_prob=0.964848, new_prob=0.964709, diff=-0.000139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 304: +epsilon -> pixel=(104,216,0), old_prob=0.964709, new_prob=0.964602, diff=-0.000106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 306: -epsilon -> pixel=(21,180,0), old_prob=0.964602, new_prob=0.964593, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 307: +epsilon -> pixel=(92,159,1), old_prob=0.964593, new_prob=0.964365, diff=-0.000229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 308: +epsilon -> pixel=(98,13,0), old_prob=0.964365, new_prob=0.964361, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 309: +epsilon -> pixel=(135,111,1), old_prob=0.964361, new_prob=0.964325, diff=-0.000037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 310: +epsilon -> pixel=(219,55,0), old_prob=0.964325, new_prob=0.964316, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 312: +epsilon -> pixel=(207,171,0), old_prob=0.964316, new_prob=0.964306, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 313: +epsilon -> pixel=(28,5,1), old_prob=0.964306, new_prob=0.964305, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 314: -epsilon -> pixel=(217,168,1), old_prob=0.964305, new_prob=0.964302, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 315: +epsilon -> pixel=(46,72,1), old_prob=0.964302, new_prob=0.964271, diff=-0.000031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 316: +epsilon -> pixel=(56,13,1), old_prob=0.964271, new_prob=0.964247, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 317: +epsilon -> pixel=(100,13,2), old_prob=0.964247, new_prob=0.964242, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 318: +epsilon -> pixel=(160,135,0), old_prob=0.964242, new_prob=0.964239, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 319: -epsilon -> pixel=(137,32,0), old_prob=0.964239, new_prob=0.964232, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# ...
# Iteration 1894: -epsilon -> pixel=(87,57,2), old_prob=0.798386, new_prob=0.798274, diff=-0.000112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 1895: +epsilon -> pixel=(82,39,1), old_prob=0.798274, new_prob=0.798204, diff=-0.000070
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Iteration 1896: +epsilon -> pixel=(219,192,0), old_prob=0.798204, new_prob=0.798101, diff=-0.000103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 1897: +epsilon -> pixel=(159,68,2), old_prob=0.798101, new_prob=0.798061, diff=-0.000041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1899: +epsilon -> pixel=(232,169,2), old_prob=0.798061, new_prob=0.798059, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 1900: +epsilon -> pixel=(148,196,1), old_prob=0.798059, new_prob=0.798043, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 1901: +epsilon -> pixel=(50,173,0), old_prob=0.798043, new_prob=0.797974, diff=-0.000070
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# Iteration 1903: -epsilon -> pixel=(191,69,0), old_prob=0.797974, new_prob=0.797908, diff=-0.000065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# Iteration 1904: +epsilon -> pixel=(5,202,2), old_prob=0.797908, new_prob=0.797880, diff=-0.000029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 1905: -epsilon -> pixel=(37,86,1), old_prob=0.797880, new_prob=0.797798, diff=-0.000081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# Iteration 1906: -epsilon -> pixel=(2,135,2), old_prob=0.797798, new_prob=0.797752, diff=-0.000046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 1907: +epsilon -> pixel=(101,74,2), old_prob=0.797752, new_prob=0.797617, diff=-0.000135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 1908: +epsilon -> pixel=(14,28,0), old_prob=0.797617, new_prob=0.797569, diff=-0.000049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Iteration 1909: +epsilon -> pixel=(150,60,2), old_prob=0.797569, new_prob=0.797412, diff=-0.000157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# Iteration 1910: +epsilon -> pixel=(158,133,1), old_prob=0.797412, new_prob=0.797244, diff=-0.000168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1911: -epsilon -> pixel=(144,122,1), old_prob=0.797244, new_prob=0.796304, diff=-0.000940
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 1912: -epsilon -> pixel=(45,198,0), old_prob=0.796304, new_prob=0.795905, diff=-0.000399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# Iteration 1914: +epsilon -> pixel=(136,192,2), old_prob=0.795905, new_prob=0.795375, diff=-0.000529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 1915: -epsilon -> pixel=(98,7,2), old_prob=0.795375, new_prob=0.795347, diff=-0.000028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# Iteration 1916: +epsilon -> pixel=(119,74,0), old_prob=0.795347, new_prob=0.795218, diff=-0.000129
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1917: +epsilon -> pixel=(212,193,1), old_prob=0.795218, new_prob=0.795173, diff=-0.000045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Iteration 1918: +epsilon -> pixel=(5,192,1), old_prob=0.795173, new_prob=0.795155, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# Iteration 1919: +epsilon -> pixel=(104,9,1), old_prob=0.795155, new_prob=0.795154, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# Iteration 1920: +epsilon -> pixel=(173,224,1), old_prob=0.795154, new_prob=0.795027, diff=-0.000127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 1921: -epsilon -> pixel=(157,119,0), old_prob=0.795027, new_prob=0.794973, diff=-0.000054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 1922: +epsilon -> pixel=(0,192,1), old_prob=0.794973, new_prob=0.794957, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 1923: -epsilon -> pixel=(161,55,2), old_prob=0.794957, new_prob=0.794951, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1924: -epsilon -> pixel=(140,181,0), old_prob=0.794951, new_prob=0.794565, diff=-0.000386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 1925: +epsilon -> pixel=(180,191,0), old_prob=0.794565, new_prob=0.794396, diff=-0.000169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 1926: +epsilon -> pixel=(179,21,0), old_prob=0.794396, new_prob=0.794346, diff=-0.000051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Iteration 1927: +epsilon -> pixel=(43,45,1), old_prob=0.794346, new_prob=0.794330, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 1928: -epsilon -> pixel=(68,32,1), old_prob=0.794330, new_prob=0.794095, diff=-0.000235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Iteration 1929: -epsilon -> pixel=(201,228,0), old_prob=0.794095, new_prob=0.794083, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 1930: -epsilon -> pixel=(122,222,1), old_prob=0.794083, new_prob=0.793752, diff=-0.000331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 1931: +epsilon -> pixel=(22,34,2), old_prob=0.793752, new_prob=0.793729, diff=-0.000023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# Iteration 1933: +epsilon -> pixel=(32,150,0), old_prob=0.793729, new_prob=0.793603, diff=-0.000126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 1934: -epsilon -> pixel=(137,233,2), old_prob=0.793603, new_prob=0.793529, diff=-0.000074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1935: -epsilon -> pixel=(114,148,0), old_prob=0.793529, new_prob=0.791530, diff=-0.001999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# Iteration 1936: -epsilon -> pixel=(139,43,1), old_prob=0.791530, new_prob=0.791495, diff=-0.000035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 1937: -epsilon -> pixel=(83,187,2), old_prob=0.791495, new_prob=0.791175, diff=-0.000320
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 1938: -epsilon -> pixel=(36,94,1), old_prob=0.791175, new_prob=0.790525, diff=-0.000650
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1939: -epsilon -> pixel=(44,237,0), old_prob=0.790525, new_prob=0.790503, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# Iteration 1940: No update at pixel=(3,29,1). pos_diff=0.000000, neg_diff=0.000000, current_prob=0.790503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 1941: +epsilon -> pixel=(114,198,1), old_prob=0.790503, new_prob=0.790460, diff=-0.000044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 1942: -epsilon -> pixel=(14,119,1), old_prob=0.790460, new_prob=0.790419, diff=-0.000040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 1943: -epsilon -> pixel=(53,71,2), old_prob=0.790419, new_prob=0.790405, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1944: -epsilon -> pixel=(180,90,2), old_prob=0.790405, new_prob=0.789902, diff=-0.000503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 1945: +epsilon -> pixel=(199,210,2), old_prob=0.789902, new_prob=0.789810, diff=-0.000092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 1946: -epsilon -> pixel=(86,12,2), old_prob=0.789810, new_prob=0.789751, diff=-0.000060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 1947: +epsilon -> pixel=(136,191,0), old_prob=0.789751, new_prob=0.789413, diff=-0.000338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 1948: -epsilon -> pixel=(57,54,0), old_prob=0.789413, new_prob=0.789399, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 1949: +epsilon -> pixel=(96,73,1), old_prob=0.789399, new_prob=0.788859, diff=-0.000540
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 1950: -epsilon -> pixel=(134,52,2), old_prob=0.788859, new_prob=0.788761, diff=-0.000099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 1951: -epsilon -> pixel=(31,25,0), old_prob=0.788761, new_prob=0.788725, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# Iteration 1952: +epsilon -> pixel=(37,120,1), old_prob=0.788725, new_prob=0.788505, diff=-0.000219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 1953: +epsilon -> pixel=(195,95,0), old_prob=0.788505, new_prob=0.788481, diff=-0.000025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 1954: -epsilon -> pixel=(237,53,1), old_prob=0.788481, new_prob=0.788410, diff=-0.000071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1955: -epsilon -> pixel=(156,62,2), old_prob=0.788410, new_prob=0.788359, diff=-0.000051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# Iteration 1956: -epsilon -> pixel=(162,99,2), old_prob=0.788359, new_prob=0.787959, diff=-0.000400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 1957: +epsilon -> pixel=(207,213,0), old_prob=0.787959, new_prob=0.787944, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 1958: -epsilon -> pixel=(204,237,1), old_prob=0.787944, new_prob=0.787885, diff=-0.000059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 1959: +epsilon -> pixel=(30,204,0), old_prob=0.787885, new_prob=0.787869, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 1960: No update at pixel=(42,176,1). pos_diff=0.000015, neg_diff=0.000548, current_prob=0.787869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1961: -epsilon -> pixel=(235,38,2), old_prob=0.787869, new_prob=0.787796, diff=-0.000073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 1962: +epsilon -> pixel=(48,93,2), old_prob=0.787796, new_prob=0.787658, diff=-0.000138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 1963: +epsilon -> pixel=(177,80,0), old_prob=0.787658, new_prob=0.787201, diff=-0.000457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 1964: +epsilon -> pixel=(63,69,2), old_prob=0.787201, new_prob=0.787006, diff=-0.000195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 984ms/step
# Iteration 1965: +epsilon -> pixel=(204,142,0), old_prob=0.787006, new_prob=0.786493, diff=-0.000513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 1966: -epsilon -> pixel=(24,204,1), old_prob=0.786493, new_prob=0.786243, diff=-0.000250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# Iteration 1967: +epsilon -> pixel=(102,12,2), old_prob=0.786243, new_prob=0.786233, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1968: -epsilon -> pixel=(209,234,2), old_prob=0.786233, new_prob=0.786171, diff=-0.000062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 1969: +epsilon -> pixel=(105,83,1), old_prob=0.786171, new_prob=0.786154, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# Iteration 1970: -epsilon -> pixel=(18,235,2), old_prob=0.786154, new_prob=0.786132, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# Iteration 1971: +epsilon -> pixel=(158,29,0), old_prob=0.786132, new_prob=0.786061, diff=-0.000071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1973: -epsilon -> pixel=(31,69,0), old_prob=0.786061, new_prob=0.785943, diff=-0.000118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1974: +epsilon -> pixel=(116,118,0), old_prob=0.785943, new_prob=0.785285, diff=-0.000658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 1975: -epsilon -> pixel=(74,49,0), old_prob=0.785285, new_prob=0.785199, diff=-0.000085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# Iteration 1976: +epsilon -> pixel=(118,192,0), old_prob=0.785199, new_prob=0.784507, diff=-0.000693
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 1977: +epsilon -> pixel=(1,185,2), old_prob=0.784507, new_prob=0.784505, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 1978: -epsilon -> pixel=(187,202,2), old_prob=0.784505, new_prob=0.784447, diff=-0.000059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 1979: +epsilon -> pixel=(141,118,0), old_prob=0.784447, new_prob=0.784385, diff=-0.000062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 1980: -epsilon -> pixel=(239,33,1), old_prob=0.784385, new_prob=0.784380, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 1981: +epsilon -> pixel=(169,38,0), old_prob=0.784380, new_prob=0.784330, diff=-0.000049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 1982: +epsilon -> pixel=(220,82,0), old_prob=0.784330, new_prob=0.784209, diff=-0.000121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Iteration 1983: +epsilon -> pixel=(203,167,1), old_prob=0.784209, new_prob=0.784173, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# Iteration 1984: +epsilon -> pixel=(73,159,0), old_prob=0.784173, new_prob=0.784054, diff=-0.000119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 1985: -epsilon -> pixel=(164,27,2), old_prob=0.784054, new_prob=0.784027, diff=-0.000027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1986: +epsilon -> pixel=(115,234,1), old_prob=0.784027, new_prob=0.784026, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1987: +epsilon -> pixel=(164,124,1), old_prob=0.784026, new_prob=0.783951, diff=-0.000075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 1988: +epsilon -> pixel=(22,137,1), old_prob=0.783951, new_prob=0.783909, diff=-0.000042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 1989: +epsilon -> pixel=(39,132,1), old_prob=0.783909, new_prob=0.783868, diff=-0.000041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Iteration 1990: +epsilon -> pixel=(65,152,0), old_prob=0.783868, new_prob=0.783721, diff=-0.000147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 1991: +epsilon -> pixel=(215,18,1), old_prob=0.783721, new_prob=0.783706, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# Iteration 1992: +epsilon -> pixel=(226,141,0), old_prob=0.783706, new_prob=0.783685, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 1993: -epsilon -> pixel=(87,155,0), old_prob=0.783685, new_prob=0.781928, diff=-0.001757
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1994: +epsilon -> pixel=(137,228,1), old_prob=0.781928, new_prob=0.781816, diff=-0.000111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1995: +epsilon -> pixel=(84,1,2), old_prob=0.781816, new_prob=0.781811, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 1996: -epsilon -> pixel=(159,19,1), old_prob=0.781811, new_prob=0.781806, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# Iteration 1997: -epsilon -> pixel=(36,206,1), old_prob=0.781806, new_prob=0.781614, diff=-0.000192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# Iteration 1998: +epsilon -> pixel=(180,151,1), old_prob=0.781614, new_prob=0.781592, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1999: +epsilon -> pixel=(202,146,0), old_prob=0.781592, new_prob=0.781434, diff=-0.000157
# Attack finished after 2000 iterations. Final true class probability: 0.7814

# %%
adv_image_path = "adv_image.ppm"
# Load and preprocess the image with the correct target size (240x240)
image = load_ppm_image(adv_image_path, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign(image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# Prediction shape: (1, 43)
# Predicted class: Speed limit 20
# np.int64(0)

# %%
display_ppm_image(adv_image_path)

# %% [markdown]
# ***Third Adverserial Example***

# %%
new_image_path = "/content/Novehicle.ppm"
# Load and preprocess the image with the correct target size (240x240)
image = load_ppm_image(new_image_path, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign_all(image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# Prediction shape: (1, 43)
# Class 0 (Speed limit 20): 0.0000
# Class 1 (Speed limit 30): 0.0002
# Class 2 (Speed limit 50): 0.0000
# Class 3 (Speed limit 60): 0.0000
# Class 4 (Speed limit 70): 0.0000
# Class 5 (Speed limit 80): 0.0001
# Class 6 (End of speed limit 80): 0.0000
# Class 7 (Speed limit 100): 0.1632
# Class 8 (Speed limit 120): 0.0000
# Class 9 (No passing): 0.0001
# Class 10 (No passing for vehicles over 3.5 tons): 0.0001
# Class 11 (Right-of-way at next intersection): 0.0000
# Class 12 (Priority road): 0.0000
# Class 13 (Yield): 0.0000
# Class 14 (Stop): 0.0000
# Class 15 (No vehicles): 0.0001
# Class 16 (Vehicles over 3.5 tons prohibited): 0.8337
# Class 17 (No entry): 0.0000
# Class 18 (General caution): 0.0000
# Class 19 (Dangerous curve left): 0.0000
# Class 20 (Dangerous curve right): 0.0000
# Class 21 (Double curve): 0.0000
# Class 22 (Bumpy road): 0.0000
# Class 23 (Slippery road): 0.0000
# Class 24 (Road narrows on the right): 0.0000
# Class 25 (Road work): 0.0000
# Class 26 (Traffic signals): 0.0000
# Class 27 (Pedestrians): 0.0000
# Class 28 (Children crossing): 0.0000
# Class 29 (Bicycles crossing): 0.0000
# Class 30 (Beware of ice/snow): 0.0000
# Class 31 (Wild animals crossing): 0.0000
# Class 32 (End of all speed and passing limits): 0.0000
# Class 33 (Turn right ahead): 0.0001
# Class 34 (Turn left ahead): 0.0000
# Class 35 (Ahead only): 0.0000
# Class 36 (Go straight or right): 0.0000
# Class 37 (Go straight or left): 0.0000
# Class 38 (Keep right): 0.0000
# Class 39 (Keep left): 0.0000
# Class 40 (Roundabout mandatory): 0.0011
# Class 41 (End of no passing): 0.0000
# Class 42 (End of no passing for vehicles over 3.5 tons): 0.0013
# Predicted class: Vehicles over 3.5 tons prohibited
# np.int64(16)

# %%
before_adverserial="/content/Novehicle.ppm"
display_ppm_image(before_adverserial)

# %%
# Example usage:
image_path = "/content/Novehicle.ppm"
model = tf.keras.models.load_model("TrafficSigns_EfficientNetB1.keras")  # Load your trained model
image_tensor = load_ppm_image(image_path, target_size=(240, 240))
true_label = predict_traffic_sign(image_tensor, model, GTSRB_CLASSES)
adv_image_tensor = simba_attack(image_tensor, true_label, model, num_iters=5000, epsilon=0.2, print_every=10)
#
# # Optionally, save or visualize the adversarial image:
adv_image = adv_image_tensor.numpy()[0].astype(np.uint8)
adv_pil = Image.fromarray(adv_image)
adv_pil.save("Restriction_adv_image.ppm")
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 761: -epsilon -> pixel=(102,5,1), old_prob=0.746460, new_prob=0.746459, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 762: -epsilon -> pixel=(96,232,0), old_prob=0.746459, new_prob=0.746442, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 763: +epsilon -> pixel=(133,130,1), old_prob=0.746442, new_prob=0.746087, diff=-0.000355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 764: +epsilon -> pixel=(50,10,1), old_prob=0.746087, new_prob=0.746084, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 765: -epsilon -> pixel=(20,141,0), old_prob=0.746084, new_prob=0.746019, diff=-0.000065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 766: -epsilon -> pixel=(142,112,2), old_prob=0.746019, new_prob=0.745996, diff=-0.000023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# Iteration 767: +epsilon -> pixel=(142,217,1), old_prob=0.745996, new_prob=0.745859, diff=-0.000138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 915ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 768: -epsilon -> pixel=(128,117,2), old_prob=0.745859, new_prob=0.745808, diff=-0.000051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 769: -epsilon -> pixel=(212,238,1), old_prob=0.745808, new_prob=0.745805, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# Iteration 770: +epsilon -> pixel=(81,60,1), old_prob=0.745805, new_prob=0.745785, diff=-0.000020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 771: -epsilon -> pixel=(59,24,2), old_prob=0.745785, new_prob=0.745759, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Iteration 772: -epsilon -> pixel=(126,26,1), old_prob=0.745759, new_prob=0.744960, diff=-0.000799
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 774: +epsilon -> pixel=(99,138,0), old_prob=0.744960, new_prob=0.744955, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Iteration 775: +epsilon -> pixel=(130,57,2), old_prob=0.744955, new_prob=0.744866, diff=-0.000089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 776: -epsilon -> pixel=(181,71,2), old_prob=0.744866, new_prob=0.743531, diff=-0.001335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# Iteration 778: -epsilon -> pixel=(74,205,0), old_prob=0.743531, new_prob=0.743495, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 779: -epsilon -> pixel=(118,193,0), old_prob=0.743495, new_prob=0.743144, diff=-0.000351
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 780: -epsilon -> pixel=(157,62,0), old_prob=0.743144, new_prob=0.742368, diff=-0.000776
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 781: -epsilon -> pixel=(71,166,0), old_prob=0.742368, new_prob=0.741641, diff=-0.000727
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 782: +epsilon -> pixel=(84,127,0), old_prob=0.741641, new_prob=0.741639, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 783: -epsilon -> pixel=(39,34,1), old_prob=0.741639, new_prob=0.741571, diff=-0.000068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 784: +epsilon -> pixel=(205,88,2), old_prob=0.741571, new_prob=0.741565, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 786: -epsilon -> pixel=(189,108,0), old_prob=0.741565, new_prob=0.740541, diff=-0.001024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 787: -epsilon -> pixel=(22,154,0), old_prob=0.740541, new_prob=0.740315, diff=-0.000226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 788: -epsilon -> pixel=(167,139,1), old_prob=0.740315, new_prob=0.739881, diff=-0.000433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 790: -epsilon -> pixel=(141,124,2), old_prob=0.739881, new_prob=0.739777, diff=-0.000104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 791: +epsilon -> pixel=(209,110,2), old_prob=0.739777, new_prob=0.739770, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Iteration 792: +epsilon -> pixel=(114,132,2), old_prob=0.739770, new_prob=0.739611, diff=-0.000159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 793: +epsilon -> pixel=(216,229,1), old_prob=0.739611, new_prob=0.739609, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Iteration 794: -epsilon -> pixel=(195,97,2), old_prob=0.739609, new_prob=0.739472, diff=-0.000137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 796: +epsilon -> pixel=(144,145,2), old_prob=0.739472, new_prob=0.739413, diff=-0.000058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Iteration 797: -epsilon -> pixel=(189,59,0), old_prob=0.739413, new_prob=0.739298, diff=-0.000115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 798: -epsilon -> pixel=(97,61,0), old_prob=0.739298, new_prob=0.739109, diff=-0.000189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Iteration 800: No update at pixel=(158,4,1). pos_diff=0.000000, neg_diff=0.000043, current_prob=0.739109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 802: -epsilon -> pixel=(79,237,1), old_prob=0.739109, new_prob=0.739042, diff=-0.000067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 803: -epsilon -> pixel=(141,131,1), old_prob=0.739042, new_prob=0.739029, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# Iteration 804: +epsilon -> pixel=(110,6,0), old_prob=0.739029, new_prob=0.738971, diff=-0.000058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 805: -epsilon -> pixel=(118,193,2), old_prob=0.738971, new_prob=0.738420, diff=-0.000551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 806: +epsilon -> pixel=(135,228,2), old_prob=0.738420, new_prob=0.738375, diff=-0.000045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 807: +epsilon -> pixel=(100,134,1), old_prob=0.738375, new_prob=0.738310, diff=-0.000065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 984ms/step
# Iteration 808: +epsilon -> pixel=(101,133,1), old_prob=0.738310, new_prob=0.738300, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 809: -epsilon -> pixel=(228,1,1), old_prob=0.738300, new_prob=0.738271, diff=-0.000029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# Iteration 810: +epsilon -> pixel=(211,193,0), old_prob=0.738271, new_prob=0.738260, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# Iteration 811: -epsilon -> pixel=(140,84,0), old_prob=0.738260, new_prob=0.738199, diff=-0.000060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 814: +epsilon -> pixel=(28,55,0), old_prob=0.738199, new_prob=0.738198, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# Iteration 815: +epsilon -> pixel=(148,96,0), old_prob=0.738198, new_prob=0.737807, diff=-0.000391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 816: -epsilon -> pixel=(71,52,0), old_prob=0.737807, new_prob=0.737749, diff=-0.000058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 817: +epsilon -> pixel=(158,209,2), old_prob=0.737749, new_prob=0.737749, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Iteration 820: +epsilon -> pixel=(191,136,1), old_prob=0.737749, new_prob=0.737735, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 821: +epsilon -> pixel=(214,5,0), old_prob=0.737735, new_prob=0.737735, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# Iteration 822: -epsilon -> pixel=(37,158,1), old_prob=0.737735, new_prob=0.737570, diff=-0.000165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 823: +epsilon -> pixel=(217,53,1), old_prob=0.737570, new_prob=0.737495, diff=-0.000075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 824: +epsilon -> pixel=(224,223,1), old_prob=0.737495, new_prob=0.737494, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 825: -epsilon -> pixel=(176,10,1), old_prob=0.737494, new_prob=0.737492, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 826: -epsilon -> pixel=(43,32,2), old_prob=0.737492, new_prob=0.737491, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# Iteration 827: -epsilon -> pixel=(114,8,1), old_prob=0.737491, new_prob=0.737403, diff=-0.000088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# Iteration 828: +epsilon -> pixel=(164,64,1), old_prob=0.737403, new_prob=0.737384, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# Iteration 830: -epsilon -> pixel=(195,78,2), old_prob=0.737384, new_prob=0.736987, diff=-0.000397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# Iteration 831: -epsilon -> pixel=(226,33,1), old_prob=0.736987, new_prob=0.736907, diff=-0.000080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 832: +epsilon -> pixel=(23,158,1), old_prob=0.736907, new_prob=0.736864, diff=-0.000043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# Iteration 833: -epsilon -> pixel=(109,97,0), old_prob=0.736864, new_prob=0.736574, diff=-0.000290
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# Iteration 835: +epsilon -> pixel=(127,174,1), old_prob=0.736574, new_prob=0.736514, diff=-0.000060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 837: +epsilon -> pixel=(35,186,2), old_prob=0.736514, new_prob=0.736493, diff=-0.000020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# Iteration 838: +epsilon -> pixel=(63,234,1), old_prob=0.736493, new_prob=0.736491, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 839: +epsilon -> pixel=(81,197,1), old_prob=0.736491, new_prob=0.736486, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 840: +epsilon -> pixel=(191,48,1), old_prob=0.736486, new_prob=0.736425, diff=-0.000060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Iteration 841: -epsilon -> pixel=(51,63,2), old_prob=0.736425, new_prob=0.736418, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# Iteration 842: +epsilon -> pixel=(102,73,1), old_prob=0.736418, new_prob=0.736379, diff=-0.000040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 843: +epsilon -> pixel=(196,20,2), old_prob=0.736379, new_prob=0.736373, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# Iteration 844: +epsilon -> pixel=(37,122,2), old_prob=0.736373, new_prob=0.736372, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 845: +epsilon -> pixel=(67,67,0), old_prob=0.736372, new_prob=0.736370, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# Iteration 846: +epsilon -> pixel=(215,66,1), old_prob=0.736370, new_prob=0.735754, diff=-0.000616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 847: +epsilon -> pixel=(221,83,0), old_prob=0.735754, new_prob=0.735752, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 848: -epsilon -> pixel=(88,32,2), old_prob=0.735752, new_prob=0.735482, diff=-0.000270
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 849: +epsilon -> pixel=(165,17,2), old_prob=0.735482, new_prob=0.735446, diff=-0.000035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 850: -epsilon -> pixel=(224,143,2), old_prob=0.735446, new_prob=0.735445, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 851: -epsilon -> pixel=(76,174,1), old_prob=0.735445, new_prob=0.733583, diff=-0.001863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# Iteration 852: +epsilon -> pixel=(45,201,1), old_prob=0.733583, new_prob=0.733480, diff=-0.000103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 853: +epsilon -> pixel=(119,159,0), old_prob=0.733480, new_prob=0.733020, diff=-0.000460
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# Iteration 856: -epsilon -> pixel=(63,102,2), old_prob=0.733020, new_prob=0.732785, diff=-0.000235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 857: -epsilon -> pixel=(84,192,1), old_prob=0.732785, new_prob=0.732330, diff=-0.000454
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 859: +epsilon -> pixel=(130,183,1), old_prob=0.732330, new_prob=0.732327, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 860: -epsilon -> pixel=(234,209,0), old_prob=0.732327, new_prob=0.732310, diff=-0.000018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 861: +epsilon -> pixel=(115,79,1), old_prob=0.732310, new_prob=0.730745, diff=-0.001565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# Iteration 862: -epsilon -> pixel=(183,49,2), old_prob=0.730745, new_prob=0.730056, diff=-0.000688
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# Iteration 863: +epsilon -> pixel=(225,142,1), old_prob=0.730056, new_prob=0.729992, diff=-0.000064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 864: +epsilon -> pixel=(17,69,0), old_prob=0.729992, new_prob=0.729978, diff=-0.000013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 865: +epsilon -> pixel=(1,135,1), old_prob=0.729978, new_prob=0.729952, diff=-0.000027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 866: -epsilon -> pixel=(74,185,0), old_prob=0.729952, new_prob=0.729080, diff=-0.000872
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 867: -epsilon -> pixel=(126,90,0), old_prob=0.729080, new_prob=0.729042, diff=-0.000038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 868: -epsilon -> pixel=(157,24,2), old_prob=0.729042, new_prob=0.729038, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 869: +epsilon -> pixel=(1,61,1), old_prob=0.729038, new_prob=0.729037, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# Iteration 870: No update at pixel=(62,160,2). pos_diff=0.000000, neg_diff=0.000242, current_prob=0.729037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 871: -epsilon -> pixel=(85,130,1), old_prob=0.729037, new_prob=0.728543, diff=-0.000493
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# Iteration 872: -epsilon -> pixel=(109,95,0), old_prob=0.728543, new_prob=0.728434, diff=-0.000109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 874: -epsilon -> pixel=(14,140,0), old_prob=0.728434, new_prob=0.728413, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Iteration 876: -epsilon -> pixel=(84,38,0), old_prob=0.728413, new_prob=0.727659, diff=-0.000755
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 877: +epsilon -> pixel=(187,177,0), old_prob=0.727659, new_prob=0.727637, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 878: -epsilon -> pixel=(27,12,2), old_prob=0.727637, new_prob=0.727585, diff=-0.000052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 879: -epsilon -> pixel=(160,226,0), old_prob=0.727585, new_prob=0.727560, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# Iteration 880: No update at pixel=(200,188,1). pos_diff=0.000185, neg_diff=0.000000, current_prob=0.727560
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 881: +epsilon -> pixel=(126,177,2), old_prob=0.727560, new_prob=0.727534, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Iteration 882: +epsilon -> pixel=(138,127,2), old_prob=0.727534, new_prob=0.727448, diff=-0.000086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# Iteration 883: +epsilon -> pixel=(175,88,0), old_prob=0.727448, new_prob=0.727333, diff=-0.000115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 884: -epsilon -> pixel=(70,1,0), old_prob=0.727333, new_prob=0.727307, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 885: -epsilon -> pixel=(47,153,1), old_prob=0.727307, new_prob=0.726909, diff=-0.000398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 886: +epsilon -> pixel=(132,88,0), old_prob=0.726909, new_prob=0.725483, diff=-0.001426
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 887: -epsilon -> pixel=(107,53,2), old_prob=0.725483, new_prob=0.725457, diff=-0.000026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 890: +epsilon -> pixel=(188,123,1), old_prob=0.725457, new_prob=0.725413, diff=-0.000044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 891: -epsilon -> pixel=(29,221,0), old_prob=0.725413, new_prob=0.725358, diff=-0.000055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 893: +epsilon -> pixel=(232,205,1), old_prob=0.725358, new_prob=0.725358, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# Iteration 895: -epsilon -> pixel=(228,109,1), old_prob=0.725358, new_prob=0.725325, diff=-0.000032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Iteration 896: -epsilon -> pixel=(230,128,2), old_prob=0.725325, new_prob=0.725323, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# Iteration 897: +epsilon -> pixel=(73,70,1), old_prob=0.725323, new_prob=0.723814, diff=-0.001509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Iteration 898: -epsilon -> pixel=(232,178,2), old_prob=0.723814, new_prob=0.723779, diff=-0.000035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 899: -epsilon -> pixel=(203,61,2), old_prob=0.723779, new_prob=0.723776, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 900: +epsilon -> pixel=(153,206,2), old_prob=0.723776, new_prob=0.723772, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 901: -epsilon -> pixel=(165,220,0), old_prob=0.723772, new_prob=0.723723, diff=-0.000049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 903: -epsilon -> pixel=(206,2,0), old_prob=0.723723, new_prob=0.723610, diff=-0.000114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 904: +epsilon -> pixel=(192,4,1), old_prob=0.723610, new_prob=0.723608, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# Iteration 906: -epsilon -> pixel=(208,109,0), old_prob=0.723608, new_prob=0.722134, diff=-0.001474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 907: -epsilon -> pixel=(182,101,1), old_prob=0.722134, new_prob=0.717594, diff=-0.004540
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# Iteration 908: -epsilon -> pixel=(163,141,0), old_prob=0.717594, new_prob=0.717526, diff=-0.000067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 910: +epsilon -> pixel=(98,98,1), old_prob=0.717526, new_prob=0.717501, diff=-0.000025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 911: +epsilon -> pixel=(47,173,1), old_prob=0.717501, new_prob=0.717489, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1000ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 912: -epsilon -> pixel=(126,234,2), old_prob=0.717489, new_prob=0.717488, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 913: -epsilon -> pixel=(108,109,2), old_prob=0.717488, new_prob=0.717427, diff=-0.000061
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# Iteration 914: -epsilon -> pixel=(30,233,0), old_prob=0.717427, new_prob=0.717373, diff=-0.000054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 915: -epsilon -> pixel=(239,225,2), old_prob=0.717373, new_prob=0.717371, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 916: +epsilon -> pixel=(115,6,2), old_prob=0.717371, new_prob=0.717322, diff=-0.000049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 917: -epsilon -> pixel=(199,58,1), old_prob=0.717322, new_prob=0.716583, diff=-0.000738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# Iteration 918: +epsilon -> pixel=(223,150,0), old_prob=0.716583, new_prob=0.716572, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# Iteration 919: -epsilon -> pixel=(76,66,2), old_prob=0.716572, new_prob=0.716561, diff=-0.000011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 920: -epsilon -> pixel=(217,41,2), old_prob=0.716561, new_prob=0.716538, diff=-0.000022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 921: +epsilon -> pixel=(206,52,1), old_prob=0.716538, new_prob=0.716304, diff=-0.000234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# Iteration 922: -epsilon -> pixel=(204,14,0), old_prob=0.716304, new_prob=0.716120, diff=-0.000184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 923: +epsilon -> pixel=(89,79,2), old_prob=0.716120, new_prob=0.716048, diff=-0.000072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 924: -epsilon -> pixel=(201,10,0), old_prob=0.716048, new_prob=0.715888, diff=-0.000160
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 925: -epsilon -> pixel=(117,125,0), old_prob=0.715888, new_prob=0.715597, diff=-0.000292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# Iteration 926: -epsilon -> pixel=(210,30,0), old_prob=0.715597, new_prob=0.715349, diff=-0.000247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 927: +epsilon -> pixel=(27,132,0), old_prob=0.715349, new_prob=0.715346, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# Iteration 928: -epsilon -> pixel=(100,215,2), old_prob=0.715346, new_prob=0.715227, diff=-0.000118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 929: +epsilon -> pixel=(91,99,2), old_prob=0.715227, new_prob=0.715192, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 930: -epsilon -> pixel=(219,199,0), old_prob=0.715192, new_prob=0.715181, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 931: +epsilon -> pixel=(126,119,2), old_prob=0.715181, new_prob=0.714731, diff=-0.000450
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Iteration 932: -epsilon -> pixel=(39,234,2), old_prob=0.714731, new_prob=0.714707, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 933: +epsilon -> pixel=(143,223,0), old_prob=0.714707, new_prob=0.714706, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 934: +epsilon -> pixel=(42,98,2), old_prob=0.714706, new_prob=0.714700, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# Iteration 936: +epsilon -> pixel=(136,81,0), old_prob=0.714700, new_prob=0.714688, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 937: +epsilon -> pixel=(113,109,1), old_prob=0.714688, new_prob=0.713812, diff=-0.000876
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 984ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 939: +epsilon -> pixel=(197,128,0), old_prob=0.713812, new_prob=0.713811, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 940: -epsilon -> pixel=(151,206,0), old_prob=0.713811, new_prob=0.713542, diff=-0.000269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 942: -epsilon -> pixel=(150,126,2), old_prob=0.713542, new_prob=0.713534, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# Iteration 943: -epsilon -> pixel=(23,25,2), old_prob=0.713534, new_prob=0.713513, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# Iteration 944: +epsilon -> pixel=(26,151,2), old_prob=0.713513, new_prob=0.713506, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 945: +epsilon -> pixel=(163,10,0), old_prob=0.713506, new_prob=0.713491, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 946: +epsilon -> pixel=(18,235,0), old_prob=0.713491, new_prob=0.713490, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 948: -epsilon -> pixel=(82,20,0), old_prob=0.713490, new_prob=0.712946, diff=-0.000545
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 949: +epsilon -> pixel=(86,27,1), old_prob=0.712946, new_prob=0.712932, diff=-0.000014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 950: -epsilon -> pixel=(218,239,0), old_prob=0.712932, new_prob=0.712915, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 951: +epsilon -> pixel=(101,138,1), old_prob=0.712915, new_prob=0.712898, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 952: -epsilon -> pixel=(85,36,1), old_prob=0.712898, new_prob=0.712621, diff=-0.000277
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 953: -epsilon -> pixel=(238,44,2), old_prob=0.712621, new_prob=0.712619, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 955: -epsilon -> pixel=(87,179,0), old_prob=0.712619, new_prob=0.712098, diff=-0.000521
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# Iteration 956: +epsilon -> pixel=(31,212,1), old_prob=0.712098, new_prob=0.712096, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 957: -epsilon -> pixel=(16,27,0), old_prob=0.712096, new_prob=0.712040, diff=-0.000057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 958: +epsilon -> pixel=(30,201,2), old_prob=0.712040, new_prob=0.712003, diff=-0.000036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 959: +epsilon -> pixel=(17,68,0), old_prob=0.712003, new_prob=0.711987, diff=-0.000017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# Iteration 960: No update at pixel=(239,7,0). pos_diff=0.000000, neg_diff=0.000037, current_prob=0.711987
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Iteration 963: -epsilon -> pixel=(222,91,1), old_prob=0.711987, new_prob=0.711968, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# Iteration 964: -epsilon -> pixel=(170,66,1), old_prob=0.711968, new_prob=0.711637, diff=-0.000331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 937ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 965: -epsilon -> pixel=(50,89,2), old_prob=0.711637, new_prob=0.711244, diff=-0.000393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 966: -epsilon -> pixel=(198,156,0), old_prob=0.711244, new_prob=0.710408, diff=-0.000836
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 967: +epsilon -> pixel=(26,58,1), old_prob=0.710408, new_prob=0.709851, diff=-0.000557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# Iteration 968: -epsilon -> pixel=(160,202,0), old_prob=0.709851, new_prob=0.709638, diff=-0.000212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 969: -epsilon -> pixel=(194,12,2), old_prob=0.709638, new_prob=0.709467, diff=-0.000171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 970: +epsilon -> pixel=(60,119,0), old_prob=0.709467, new_prob=0.709455, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 971: +epsilon -> pixel=(55,239,2), old_prob=0.709455, new_prob=0.709454, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# Iteration 973: -epsilon -> pixel=(60,124,2), old_prob=0.709454, new_prob=0.709121, diff=-0.000334
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# Iteration 974: +epsilon -> pixel=(152,208,2), old_prob=0.709121, new_prob=0.709113, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 975: -epsilon -> pixel=(199,137,1), old_prob=0.709113, new_prob=0.708808, diff=-0.000305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 976: -epsilon -> pixel=(93,135,0), old_prob=0.708808, new_prob=0.708776, diff=-0.000032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 977: -epsilon -> pixel=(24,136,0), old_prob=0.708776, new_prob=0.707960, diff=-0.000816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Iteration 978: -epsilon -> pixel=(142,77,1), old_prob=0.707960, new_prob=0.707955, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 980: +epsilon -> pixel=(151,73,2), old_prob=0.707955, new_prob=0.707892, diff=-0.000064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Iteration 982: -epsilon -> pixel=(31,41,1), old_prob=0.707892, new_prob=0.707883, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# Iteration 983: +epsilon -> pixel=(210,28,2), old_prob=0.707883, new_prob=0.707883, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 984ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 984: -epsilon -> pixel=(156,189,1), old_prob=0.707883, new_prob=0.707562, diff=-0.000321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 985: +epsilon -> pixel=(219,48,2), old_prob=0.707562, new_prob=0.707562, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 986: -epsilon -> pixel=(106,15,0), old_prob=0.707562, new_prob=0.707013, diff=-0.000549
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 987: -epsilon -> pixel=(239,122,0), old_prob=0.707013, new_prob=0.706945, diff=-0.000068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 988: -epsilon -> pixel=(133,174,1), old_prob=0.706945, new_prob=0.706923, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Iteration 989: +epsilon -> pixel=(37,95,2), old_prob=0.706923, new_prob=0.706916, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 990: +epsilon -> pixel=(21,138,2), old_prob=0.706916, new_prob=0.706907, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Iteration 991: +epsilon -> pixel=(195,132,2), old_prob=0.706907, new_prob=0.706895, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# Iteration 992: -epsilon -> pixel=(97,220,1), old_prob=0.706895, new_prob=0.706888, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# Iteration 993: +epsilon -> pixel=(144,1,2), old_prob=0.706888, new_prob=0.706885, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 994: +epsilon -> pixel=(24,98,1), old_prob=0.706885, new_prob=0.706856, diff=-0.000029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# Iteration 996: +epsilon -> pixel=(110,49,1), old_prob=0.706856, new_prob=0.706847, diff=-0.000009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# Iteration 999: +epsilon -> pixel=(220,95,0), old_prob=0.706847, new_prob=0.706823, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 1000: +epsilon -> pixel=(95,211,0), old_prob=0.706823, new_prob=0.706817, diff=-0.000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1001: +epsilon -> pixel=(71,206,2), old_prob=0.706817, new_prob=0.706778, diff=-0.000038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 1002: +epsilon -> pixel=(77,161,0), old_prob=0.706778, new_prob=0.706545, diff=-0.000233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 1004: -epsilon -> pixel=(2,161,2), old_prob=0.706545, new_prob=0.706505, diff=-0.000040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1005: +epsilon -> pixel=(83,35,1), old_prob=0.706505, new_prob=0.706504, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1006: +epsilon -> pixel=(3,12,2), old_prob=0.706504, new_prob=0.706502, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 1007: -epsilon -> pixel=(29,144,2), old_prob=0.706502, new_prob=0.706373, diff=-0.000129
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1000ms/step
# Iteration 1008: -epsilon -> pixel=(228,207,0), old_prob=0.706373, new_prob=0.706358, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# Iteration 1009: -epsilon -> pixel=(27,157,2), old_prob=0.706358, new_prob=0.706163, diff=-0.000195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 1010: +epsilon -> pixel=(68,22,1), old_prob=0.706163, new_prob=0.705892, diff=-0.000271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# Iteration 1011: +epsilon -> pixel=(42,26,2), old_prob=0.705892, new_prob=0.705890, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 1012: -epsilon -> pixel=(138,149,1), old_prob=0.705890, new_prob=0.705875, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1013: -epsilon -> pixel=(230,39,1), old_prob=0.705875, new_prob=0.705833, diff=-0.000042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# Iteration 1014: +epsilon -> pixel=(21,79,2), old_prob=0.705833, new_prob=0.705584, diff=-0.000249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1015: -epsilon -> pixel=(31,171,0), old_prob=0.705584, new_prob=0.705572, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 1017: -epsilon -> pixel=(233,174,0), old_prob=0.705572, new_prob=0.705553, diff=-0.000019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 1018: +epsilon -> pixel=(7,235,1), old_prob=0.705553, new_prob=0.705552, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 1019: -epsilon -> pixel=(218,124,0), old_prob=0.705552, new_prob=0.705397, diff=-0.000156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# Iteration 1020: No update at pixel=(46,138,1). pos_diff=0.000002, neg_diff=0.000826, current_prob=0.705397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Iteration 1021: +epsilon -> pixel=(212,232,1), old_prob=0.705397, new_prob=0.705395, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 1022: +epsilon -> pixel=(86,225,1), old_prob=0.705395, new_prob=0.705342, diff=-0.000053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# Iteration 2132: +epsilon -> pixel=(225,93,2), old_prob=0.512594, new_prob=0.512497, diff=-0.000097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2133: -epsilon -> pixel=(65,143,0), old_prob=0.512497, new_prob=0.512229, diff=-0.000268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2134: +epsilon -> pixel=(140,40,1), old_prob=0.512229, new_prob=0.512213, diff=-0.000015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# Iteration 2135: -epsilon -> pixel=(222,41,0), old_prob=0.512213, new_prob=0.512147, diff=-0.000066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 2136: +epsilon -> pixel=(10,173,2), old_prob=0.512147, new_prob=0.512141, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 2137: +epsilon -> pixel=(182,38,0), old_prob=0.512141, new_prob=0.512129, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2138: +epsilon -> pixel=(187,27,0), old_prob=0.512129, new_prob=0.512095, diff=-0.000034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Iteration 2139: +epsilon -> pixel=(48,5,0), old_prob=0.512095, new_prob=0.512094, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Iteration 2140: No update at pixel=(181,61,0). pos_diff=0.000003, neg_diff=0.000065, current_prob=0.512094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 2141: -epsilon -> pixel=(31,227,0), old_prob=0.512094, new_prob=0.512073, diff=-0.000020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 2142: -epsilon -> pixel=(212,102,0), old_prob=0.512073, new_prob=0.511733, diff=-0.000341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# Iteration 2143: -epsilon -> pixel=(226,92,1), old_prob=0.511733, new_prob=0.511369, diff=-0.000364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 2144: +epsilon -> pixel=(106,94,0), old_prob=0.511369, new_prob=0.511291, diff=-0.000077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2145: +epsilon -> pixel=(116,140,2), old_prob=0.511291, new_prob=0.510796, diff=-0.000496
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# Iteration 2146: -epsilon -> pixel=(110,188,0), old_prob=0.510796, new_prob=0.509573, diff=-0.001223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 2147: +epsilon -> pixel=(208,95,2), old_prob=0.509573, new_prob=0.509563, diff=-0.000010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 2148: +epsilon -> pixel=(17,40,2), old_prob=0.509563, new_prob=0.509559, diff=-0.000004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2149: -epsilon -> pixel=(224,5,1), old_prob=0.509559, new_prob=0.509523, diff=-0.000037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2150: -epsilon -> pixel=(114,153,1), old_prob=0.509523, new_prob=0.509495, diff=-0.000028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# Iteration 2151: -epsilon -> pixel=(169,36,2), old_prob=0.509495, new_prob=0.509270, diff=-0.000225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2152: +epsilon -> pixel=(51,231,1), old_prob=0.509270, new_prob=0.509267, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2155: -epsilon -> pixel=(34,76,0), old_prob=0.509267, new_prob=0.508738, diff=-0.000528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 2157: +epsilon -> pixel=(177,122,1), old_prob=0.508738, new_prob=0.508714, diff=-0.000024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# Iteration 2160: No update at pixel=(197,170,1). pos_diff=0.000000, neg_diff=0.000181, current_prob=0.508714
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 2161: +epsilon -> pixel=(46,210,2), old_prob=0.508714, new_prob=0.508683, diff=-0.000031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Iteration 2162: +epsilon -> pixel=(62,1,1), old_prob=0.508683, new_prob=0.508680, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 2163: +epsilon -> pixel=(101,110,0), old_prob=0.508680, new_prob=0.508647, diff=-0.000033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# Iteration 2164: -epsilon -> pixel=(220,119,2), old_prob=0.508647, new_prob=0.508542, diff=-0.000106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2165: -epsilon -> pixel=(32,8,2), old_prob=0.508542, new_prob=0.508498, diff=-0.000044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 984ms/step
# Iteration 2166: +epsilon -> pixel=(14,234,1), old_prob=0.508498, new_prob=0.508497, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 2167: -epsilon -> pixel=(103,233,0), old_prob=0.508497, new_prob=0.508285, diff=-0.000212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 2168: +epsilon -> pixel=(25,229,2), old_prob=0.508285, new_prob=0.508285, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2169: -epsilon -> pixel=(30,70,2), old_prob=0.508285, new_prob=0.508269, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Iteration 2170: +epsilon -> pixel=(169,48,2), old_prob=0.508269, new_prob=0.508261, diff=-0.000008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# Iteration 2171: -epsilon -> pixel=(170,233,2), old_prob=0.508261, new_prob=0.508260, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2172: -epsilon -> pixel=(195,67,0), old_prob=0.508260, new_prob=0.508128, diff=-0.000132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Iteration 2173: -epsilon -> pixel=(55,145,1), old_prob=0.508128, new_prob=0.507055, diff=-0.001073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# Iteration 2174: -epsilon -> pixel=(180,84,1), old_prob=0.507055, new_prob=0.503828, diff=-0.003228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2175: -epsilon -> pixel=(94,87,2), old_prob=0.503828, new_prob=0.503822, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# Iteration 2176: +epsilon -> pixel=(210,51,1), old_prob=0.503822, new_prob=0.503743, diff=-0.000079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# Iteration 2177: -epsilon -> pixel=(10,152,0), old_prob=0.503743, new_prob=0.503542, diff=-0.000200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Iteration 2178: +epsilon -> pixel=(160,31,0), old_prob=0.503542, new_prob=0.503494, diff=-0.000048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 2180: No update at pixel=(104,11,1). pos_diff=0.000069, neg_diff=0.000000, current_prob=0.503494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 2182: -epsilon -> pixel=(49,7,1), old_prob=0.503494, new_prob=0.503435, diff=-0.000059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 2183: +epsilon -> pixel=(105,45,2), old_prob=0.503435, new_prob=0.503434, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Iteration 2184: +epsilon -> pixel=(100,230,2), old_prob=0.503434, new_prob=0.503394, diff=-0.000040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 915ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2186: +epsilon -> pixel=(210,179,0), old_prob=0.503394, new_prob=0.503394, diff=-0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 2187: +epsilon -> pixel=(159,42,1), old_prob=0.503394, new_prob=0.503389, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 2188: -epsilon -> pixel=(143,96,1), old_prob=0.503389, new_prob=0.503377, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# Iteration 2190: +epsilon -> pixel=(16,177,1), old_prob=0.503377, new_prob=0.503322, diff=-0.000054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# Iteration 2191: +epsilon -> pixel=(17,145,0), old_prob=0.503322, new_prob=0.503292, diff=-0.000030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Iteration 2192: +epsilon -> pixel=(166,182,2), old_prob=0.503292, new_prob=0.503287, diff=-0.000005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2193: -epsilon -> pixel=(80,177,2), old_prob=0.503287, new_prob=0.502907, diff=-0.000380
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# Iteration 2194: +epsilon -> pixel=(96,113,0), old_prob=0.502907, new_prob=0.502901, diff=-0.000006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Iteration 2195: +epsilon -> pixel=(153,126,2), old_prob=0.502901, new_prob=0.502452, diff=-0.000448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Iteration 2196: +epsilon -> pixel=(139,27,2), old_prob=0.502452, new_prob=0.502451, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Iteration 2198: -epsilon -> pixel=(153,55,2), old_prob=0.502451, new_prob=0.502265, diff=-0.000186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 2199: +epsilon -> pixel=(177,141,2), old_prob=0.502265, new_prob=0.502264, diff=-0.000001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2200: No update at pixel=(151,162,0). pos_diff=0.000001, neg_diff=0.000017, current_prob=0.502264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Iteration 2201: -epsilon -> pixel=(165,54,2), old_prob=0.502264, new_prob=0.502058, diff=-0.000206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 2202: -epsilon -> pixel=(153,52,1), old_prob=0.502058, new_prob=0.501387, diff=-0.000670
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 2203: +epsilon -> pixel=(20,133,2), old_prob=0.501387, new_prob=0.501115, diff=-0.000272
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Iteration 2205: +epsilon -> pixel=(100,9,0), old_prob=0.501115, new_prob=0.501113, diff=-0.000002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# Iteration 2206: -epsilon -> pixel=(64,23,2), old_prob=0.501113, new_prob=0.501110, diff=-0.000003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# Iteration 2207: -epsilon -> pixel=(42,82,2), old_prob=0.501110, new_prob=0.500480, diff=-0.000630
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# Iteration 2208: +epsilon -> pixel=(8,163,2), old_prob=0.500480, new_prob=0.500408, diff=-0.000073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# Iteration 2209: +epsilon -> pixel=(111,110,1), old_prob=0.500408, new_prob=0.499611, diff=-0.000796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2210: No update at pixel=(66,231,2). pos_diff=0.000001, neg_diff=0.000005, current_prob=0.499611
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# Iteration 2211: -epsilon -> pixel=(101,58,2), old_prob=0.499611, new_prob=0.499564, diff=-0.000048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 2212: +epsilon -> pixel=(162,119,0), old_prob=0.499564, new_prob=0.499551, diff=-0.000012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Iteration 2213: +epsilon -> pixel=(78,78,1), old_prob=0.499551, new_prob=0.498268, diff=-0.001284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Iteration 2214: +epsilon -> pixel=(144,4,2), old_prob=0.498268, new_prob=0.498247, diff=-0.000021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# Iteration 2215: -epsilon -> pixel=(149,166,1), old_prob=0.498247, new_prob=0.498230, diff=-0.000016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Iteration 2217: +epsilon -> pixel=(137,90,1), old_prob=0.498230, new_prob=0.497087, diff=-0.001144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Attack successful at iteration 2217: predicted class flipped to 7 != true label 16
# Attack finished after 2218 iterations. Final true class probability: 0.4971

# %%
# # Optionally, save or visualize the adversarial image:
adv_image = adv_image_tensor.numpy()[0].astype(np.uint8)
adv_pil = Image.fromarray(adv_image)
adv_pil.save("threetons_adv_image.ppm")

# %%
adv_image_path = "/content/threetons_adv_image.ppm"
# Load and preprocess the image with the correct target size (240x240)
adv_image = load_ppm_image(adv_image_path, target_size=(240, 240))
# Call your prediction function with the image, model, and class mapping
predict_traffic_sign_all(adv_image, model, GTSRB_CLASSES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# Prediction shape: (1, 43)
# Class 0 (Speed limit 20): 0.0000
# Class 1 (Speed limit 30): 0.0004
# Class 2 (Speed limit 50): 0.0001
# Class 3 (Speed limit 60): 0.0000
# Class 4 (Speed limit 70): 0.0000
# Class 5 (Speed limit 80): 0.0002
# Class 6 (End of speed limit 80): 0.0000
# Class 7 (Speed limit 100): 0.4983
# Class 8 (Speed limit 120): 0.0000
# Class 9 (No passing): 0.0002
# Class 10 (No passing for vehicles over 3.5 tons): 0.0001
# Class 11 (Right-of-way at next intersection): 0.0000
# Class 12 (Priority road): 0.0000
# Class 13 (Yield): 0.0000
# Class 14 (Stop): 0.0000
# Class 15 (No vehicles): 0.0002
# Class 16 (Vehicles over 3.5 tons prohibited): 0.4971
# Class 17 (No entry): 0.0000
# Class 18 (General caution): 0.0000
# Class 19 (Dangerous curve left): 0.0000
# Class 20 (Dangerous curve right): 0.0000
# Class 21 (Double curve): 0.0000
# Class 22 (Bumpy road): 0.0000
# Class 23 (Slippery road): 0.0000
# Class 24 (Road narrows on the right): 0.0000
# Class 25 (Road work): 0.0000
# Class 26 (Traffic signals): 0.0000
# Class 27 (Pedestrians): 0.0000
# Class 28 (Children crossing): 0.0000
# Class 29 (Bicycles crossing): 0.0000
# Class 30 (Beware of ice/snow): 0.0000
# Class 31 (Wild animals crossing): 0.0000
# Class 32 (End of all speed and passing limits): 0.0000
# Class 33 (Turn right ahead): 0.0001
# Class 34 (Turn left ahead): 0.0000
# Class 35 (Ahead only): 0.0000
# Class 36 (Go straight or right): 0.0000
# Class 37 (Go straight or left): 0.0000
# Class 38 (Keep right): 0.0001
# Class 39 (Keep left): 0.0000
# Class 40 (Roundabout mandatory): 0.0013
# Class 41 (End of no passing): 0.0000
# Class 42 (End of no passing for vehicles over 3.5 tons): 0.0018
# Predicted class: Speed limit 100
# np.int64(7)

# %%
display_ppm_image(adv_image_path)
